# %%
import os
import sys,re
import numpy as np
from copy import deepcopy
from scipy import sparse
from tqdm.notebook import tqdm
from collections import Counter,defaultdict

# %%
# import lightgbm as lgb
# from lightgbm import LGBMClassifier 


from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import PassiveAggressiveClassifier


from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB,BernoulliNB


from sklearn.model_selection import GridSearchCV
from sklearn import model_selection

# %%
train_file_conllu  = r'.\TreeBanks\universal_hindi\hi_hdtb-ud-train.conllu'
train_file_sentences  = r'.\TreeBanks\universal_hindi\hi_hdtb-ud-train.txt'


val_file_conllu  = r'.\TreeBanks\universal_hindi\hi_hdtb-ud-dev.conllu'
val_file_sentences  = r'.\TreeBanks\universal_hindi\hi_hdtb-ud-dev.txt'


test_file_conllu  = r'.\TreeBanks\universal_hindi\hi_hdtb-ud-test.conllu'
test_file_sentences  = r'.\TreeBanks\universal_hindi\hi_hdtb-ud-test.txt'

# %%
def read_file(file_name):
    f = open(file_name,encoding = 'utf-8')
    lines = f.readlines()
    for i in range(len(lines)):
        lines[i] = lines[i].rstrip().split('\t')
    f.close()
    return lines

# %%
class defaultList(list):
    """A list that returns a default value if index out of bounds."""
    def __init__(self, default=None):
        self.default = default
        list.__init__(self)

    def __getitem__(self, index):
        try:
            return list.__getitem__(self, index)
        except IndexError:
            return self.default

# %%
SHIFT = 0; RIGHT = 1; LEFT = 2
MOVES = [SHIFT, RIGHT, LEFT]

# %%
class Parse(object):
    def __init__(self,size):
        
        self.size = size
        self.heads = [None]*(size + 1)
        self.left_arc = []
        self.right_arc = []
        
        for i in range(size+1):
            self.left_arc.append(defaultList(0))
            self.right_arc.append(defaultList(0))
            
        
        
    def add_arc(self,head,child):
        
        self.heads[child] = head
        
        if child < head:
            self.left_arc[head].append(child)
        else:
            self.right_arc[head].append(child)

# %%
def transition(move, i, stack, parse):
    
    
    global SHIFT, RIGHT, LEFT
    if move == SHIFT:
        stack.append(i)
        return i + 1
    elif move == RIGHT:
        parse.add_arc(stack[-2], stack.pop())
        return i
    elif move == LEFT:
        parse.add_arc(i, stack.pop())
        return i

# %%
class DependencyParser:
    def __init__(self,train_treebank,test_treebank=None):
        self.features = list()
        self.labels = list()
        self.train_treebank = train_treebank
        self.test_treebank = test_treebank
        
        self.feature_vocabulary = defaultdict()
        self.label_vocabulary = defaultdict()
        
        self.reverse_features = list()
        self.reverse_labels = list()
        
        self.classifier = None
        self.max_features = 0
    
    def check_if_tree_is_connected(self,begin,dependent_head,token_heads):     
        current = begin
        while current is not 0:
            current = token_heads[current]
            if current == dependent_head:
                return True
        
        return False
    
    def check_projectivity(self,line_tokens):
        token_heads = defaultdict()
        
        for fields in line_tokens:
            token_id = fields[0]
            token_head = fields[3]
            
            if token_heads.get(token_id) == None: # not seen before
                token_heads[token_id] = token_head
        
        for dependent in token_heads:
            
            dependent_head = token_heads[dependent]
            left = 1 + min(dependent_head,dependent)
            right = max(dependent_head,dependent)
            
            for i in range(left,right):
                
                if self.check_if_tree_is_connected(i,dependent_head,token_heads) == False:
                    return False
        
        return True
    
    def check_condition(self,buffer,stack,dependencies = {},condition=None):
        
        if(condition == '0'):
            return len(buffer) is 0 and len(stack) is 1 and stack[0] == 0
        
        elif(condition == '1'):
            #condition for shift
            return len(stack) < 2 and len(buffer) > 0 #stack has only root and items are still in buffer
    
        elif(condition == '2'): #condition for left arc
            stack_top = stack[-1]
            stack_2nd = stack[-2]
            
            return dependencies.get(stack_top) is not None and (stack_top,stack_2nd) in dependencies[stack_top]
        
        elif(condition == '3'): #condition for right arc
            stack_top = stack[-1]
            stack_2nd = stack[-2]
            
            return dependencies.get(stack_2nd) is not None and (stack_2nd,stack_top) in dependencies[stack_2nd]
        

                
    def tree_to_actions(self,buffer,stack,arcs,dependencies):
        def perform_shift(buffer,stack,arcs,configuration_states,gold_transitions):
                configuration_states.append((list(buffer), list(stack), list(arcs)))
    
                gold_transitions.append("shift")
    
                stack.append(buffer.pop())
        
        def perform_arc(arc_label,buffer,stack,arcs,configuration_states,gold_transitions,arc_type):
            configuration_states.append((list(buffer), list(stack), list(arcs)))
            
            action = f'{arc_type}_{arc_label}'
            
            gold_transitions.append(action)
            
            
            left = stack[-1]
            right = stack[-2]
            
            if arc_type == 'left':
                arcs.append((arc_label,left,right))
                stack.pop(-2)
                
            elif arc_type == 'right':
                arcs.append((arc_label,right,left))
                stack.pop()
        
        configuration_states = list() #[(buf,stk,arc)...]
        gold_transitions = list() #[shift or left_rel or right_rel] actions for each state
        
        seen_dependencies = defaultdict()
        
        while( len(buffer) >= 0 ):
            if self.check_condition(buffer,stack,condition = '0'):
                return configuration_states , gold_transitions
            
            if self.check_condition(buffer,stack,condition = '1'):
                perform_shift(buffer,stack,arcs,configuration_states,gold_transitions)
                continue
                
            stack_top = stack[-1]
            stack_2nd = stack[-2]
            
            if self.check_condition(buffer,stack,dependencies,condition = '2'):
                arc_label = dependencies[stack_top][(stack_top,stack_2nd)]
                
                perform_arc(arc_label, buffer,stack,arcs,
                           configuration_states,gold_transitions,
                           arc_type = 'left')
                
                seen_dependencies[stack_2nd] = 1
                
            elif self.check_condition(buffer,stack,dependencies,condition = '3'):
                if( dependencies.get(stack_top) is not None and any([child not in seen_dependencies for _,child in dependencies[stack_top]]) ):
                    
                    perform_shift(buffer,stack,arcs,configuration_states,gold_transitions)
                    
                else:                 
                    arc_label = dependencies[stack_2nd][(stack_2nd,stack_top)]
                
                    perform_arc(arc_label, buffer,stack,arcs,
                           configuration_states,gold_transitions,
                           arc_type = 'right')
                
                    seen_dependencies[stack_top] = 1

            else:
                perform_shift(buffer,stack,arcs,configuration_states,gold_transitions)
                
        
    def extract_configs_transitions(self,line_tokens):
        
        stack,buffer,arcs = list(),list(),list()
        dependencies = defaultdict(lambda: defaultdict())
        
        stack.append(0) #add root
        
        for tokens in reversed(line_tokens):
            tok_id,word,x_pos,head,dependecy_relation = tokens
            
            head_tok_id = (head,tok_id)
                
            dependencies[head][head_tok_id] = dependecy_relation
            
            buffer.append(tok_id)
            
        return self.tree_to_actions(buffer,stack,arcs,dependencies)
    
    def extract_features(self,current_configuration,current_transtion,
                            tree_dependencies,tokens_dict,POS_tags):

        
        def get_stackcontext_features(context_type,stack):
            
            stack_len = len(stack)
            if context_type == 'words':
                if stack_len >= 4:
                    return tokens_dict[stack[-1]],tokens_dict[stack[-2]],tokens_dict[stack[-3]]
                elif stack_len >=3:
                    return tokens_dict[stack[-1]],tokens_dict[stack[-2]],''
                elif stack_len >= 2:
                    return tokens_dict[stack[-1]],'',''
                else:
                    return '','',''
            
            if context_type == 'POS_tags':
                if stack_len >= 4:
                    return POS_tags[stack[-1]],POS_tags[stack[-2]],POS_tags[stack[-3]]
                elif stack_len >=3:
                    return POS_tags[stack[-1]],POS_tags[stack[-2]],''
                elif stack_len >= 2:
                    return POS_tags[stack[-1]],'',''
                else:
                    return '','',''
                
                
        def get_buffercontext_features(context_type,buffer):
            buffer_len = len(buffer)
            num_words = len(tokens_dict) - 1
            
            if buffer_len > 0:
                if context_type == 'words':
                    if buffer_len >=3:
                        return tokens_dict[buffer[-1]],tokens_dict[buffer[-2]],tokens_dict[buffer[-3]]

                    elif buffer_len >= 2:
                        return tokens_dict[buffer[-1]], tokens_dict[buffer[-2]],''

                    elif buffer_len>=1:
                        return tokens_dict[buffer[-1]],'',''

                if context_type == 'POS_tags':
                    if buffer_len >=3:
                        return POS_tags[buffer[-1]],POS_tags[buffer[-2]],POS_tags[buffer[-3]]

                    elif buffer_len >= 2:
                        return POS_tags[buffer[-1]], POS_tags[buffer[-2]],''

                    elif buffer_len>=1:
                        return POS_tags[buffer[-1]],'',''
            else:
                return '','',''
                        
        def get_node_children(word,data,subtree):
            
            if word == -1 :
                return 0,'',''
            
            dependents = subtree[word]
            valency = len(dependents)
            
            if not valency:
                return 0,'',''
            
            elif valency == 1:
                return 1,data[dependents[-1]],''
            else:
                return valency,data[dependents[-1]],data[dependents[-2]]
            
            
        def get_stack_features(idx,stack,tokens_dict,POS_tags):
            if idx == 'top':
                return tokens_dict[stack[-1]],POS_tags[stack[-1]]
            elif idx == '2nd_top':
                return tokens_dict[stack[-2]],POS_tags[stack[-2]]
        
        def get_buffer_features(buffer,tokens_dict,POS_tags):
                return tokens_dict[buffer[-1]],POS_tags[buffer[-1]]
            
        def get_two_word_features(tokens_dict,stack,POS_tags):
            return tokens_dict[stack[-1]],POS_tags[stack[-1]],POS_tags[stack[-2]]
        
        def insert_to_features(features,feat_i,feat_j,feat_k):
            features[feat_i] = 1
            features[feat_j] = 1
            features[feat_k] = 1
              
        
        label = current_transtion
        buffer,stack,arcs = current_configuration       
        features = defaultdict()
        
        stack_len = len(stack)
        buff_len = len(buffer)
        
        if stack_len > 1:
            stack_top = stack[-1] 
            
        else:
            stack_top = -1
        
        if len(buffer)>=1:
            curr_word = buffer[-1]
        else:
            curr_word = -1
            
        
        #print(f'st top {stack_top}, curr word {curr_word}')
        
        if len(stack) > 0:
            top_token,top_pos = get_stack_features('top',stack,tokens_dict,POS_tags)
        
            top_feature_1 = f'stack_top_{top_token}'
            top_feature_2 = f'stack_pos_{top_pos}'
            top_feature_3 = f'stack_top_pos_{top_token}_{top_pos}'
            
            insert_to_features(features,top_feature_1,top_feature_2,top_feature_3)
        
        if len(stack) > 1:
            top2nd_token,top2nd_pos = get_stack_features('2nd_top',stack,tokens_dict,POS_tags)
        
            top2nd_feature_4 = f'stack2nd_top_{top2nd_token}'
            top2nd_feature_5 = f'stack2nd_pos_{top2nd_pos}'
            top2nd_feature_6 = f'stack2nd_top_pos_{top2nd_token}_{top2nd_pos}'
            
            insert_to_features(features,top2nd_feature_4,top2nd_feature_5,top2nd_feature_6)
            
        if len(buffer) > 0:
            buf_token,buf_pos = get_buffer_features(buffer,tokens_dict,POS_tags)
        
            buf_feature_7 = f'buffer_top_{buf_token}'
            buf_feature_8 = f'buffer_pos_{buf_pos}'
            buf_feature_9 = f'buffer_top_pos_{buf_token}_{buf_pos}'
            
            insert_to_features(features,buf_feature_7,buf_feature_8,buf_feature_9)
            
            
        if len(stack) > 1 : 
            stack_top1 , pos_top1 , pos_2nd_top1 = get_two_word_features(tokens_dict,stack,POS_tags)
            
            two_word_feature_10 = f'stack_top_pos_top_pos_2ndtop_{stack_top1}_{pos_top1}_{pos_2nd_top1}'
            features[two_word_feature_10] = 1
        
        
        word_st_top,word_st_2ndtop,word_st_3rdtop = get_stackcontext_features('words',stack)
        POS_st_top,POS_st_2ndtop,POS_st_3rdtop = get_stackcontext_features('POS_tags',stack)
        
        
        word_buf_top,word_buf_2ndtop,word_buf_3rdtop = get_buffercontext_features('words',buffer)
        POS_buf_top,POS_buf_2ndtop,POS_buf_3rdtop = get_buffercontext_features('POS_tags',buffer)
        
        
        bufleft_word_val,bufleft_word_child1,bufleft_word_child2 = get_node_children(curr_word,tokens_dict,
                                                                            tree_dependencies.left_arc)
        bufleft_tag_val,bufleft_tag_child1,bufleft_tag_child2 = get_node_children(curr_word,POS_tags,
                                                                            tree_dependencies.left_arc)
        
        bufright_word_val,bufright_word_child1,bufright_word_child2 = get_node_children(curr_word,tokens_dict,
                                                                            tree_dependencies.right_arc)
        _,bufright_tag_child1,bufright_tag_child2 = get_node_children(curr_word,POS_tags,
                                                                            tree_dependencies.right_arc)

        
        stleft_word_val,stleft_word_child1,stleft_word_child2 = get_node_children(stack_top,tokens_dict,
                                                                            tree_dependencies.left_arc)
        _,stleft_tag_child1,stleft_tag_child2 = get_node_children(stack_top,POS_tags,
                                                                            tree_dependencies.left_arc)
        
        
        stright_word_val,stright_word_child1,stright_word_child2 = get_node_children(stack_top,tokens_dict,
                                                                            tree_dependencies.right_arc)
        _,stright_tag_child1,stright_tag_child2 = get_node_children(stack_top,POS_tags,
                                                                            tree_dependencies.right_arc)
        
        distance = 0
        
        if stack_top != 0 and curr_word != -1:
            distance  = min(curr_word - stack_top,5)
        
        word_feats = defaultdict(list)
        tag_feats = defaultdict(list)
        
        word_feats['stack_word'] = [word_st_top,word_st_2ndtop,word_st_3rdtop]
        word_feats['buffer_word'] = [word_buf_top,word_buf_2ndtop,word_buf_3rdtop]
        
        word_feats['left_parse_buffer'] = [bufleft_word_child1,bufleft_word_child2]
        word_feats['right_parse_buffer'] = [bufright_word_child1,bufright_word_child2]
        
        word_feats['left_parse_stack'] = [stleft_word_child1,stleft_word_child2]
        word_feats['right_parse_stack'] = [stright_word_child1,stright_word_child2]
        
        tag_feats['stack_pos'] =  [POS_st_top,POS_st_2ndtop,POS_st_3rdtop]
        tag_feats['buffer_pos'] = [POS_buf_top,POS_buf_2ndtop,POS_buf_3rdtop]
        
        tag_feats['left_parse_buffer'] = [bufleft_tag_child1,bufleft_tag_child2]
        tag_feats['right_parse_buffer'] = [bufright_tag_child1,bufright_tag_child2]
        
        tag_feats['left_parse_stack'] = [stleft_tag_child1,stleft_tag_child2]
        tag_feats['right_parse_stack'] =[stright_tag_child1,stright_tag_child2]
                
#         for feat_name,curr_feat in word_feats.items():
#             for word in curr_feat:
#                 if word:
#                     features[f'word = {word}']=1
                    
#         for feat_name,curr_feat in tag_feats.items():
#             for tag in curr_feat:
#                 if word:
#                     features[f'tag = {tag}']=1
        
        context_features = defaultdict(tuple)
        
        context_features['word_tag_pairs'] = (
            (word_st_top,POS_st_top),
            (word_buf_top,POS_buf_top),
            (word_buf_2ndtop,POS_buf_2ndtop),
            (word_buf_3rdtop,POS_buf_3rdtop)
                         )
        
        context_features['bigram_features'] = (
            (word_st_top,word_buf_top),
            (POS_st_top,POS_buf_top),
            (POS_buf_top,POS_buf_2ndtop),
#             (word_buf_top,POS_buf_top,word_st_top),
#             (word_buf_top,POS_buf_top,POS_st_top),
#             (word_st_top,POS_st_top,word_buf_top),
#             (word_st_top,POS_st_top,POS_buf_top),
#             (word_st_top,POS_st_top,word_buf_top,POS_buf_top)
        )
        
        context_features['trigram_features'] = (
            (POS_buf_top,POS_buf_2ndtop,POS_buf_3rdtop),
            (POS_st_top,POS_buf_top,POS_buf_2ndtop),
            (POS_st_top,POS_st_2ndtop,POS_buf_top),
            (POS_st_top,stright_tag_child1,POS_buf_top),
            (POS_st_top,POS_buf_top,bufleft_tag_child1),
            (POS_st_top,stleft_tag_child1,stleft_tag_child2),
            (POS_st_top,stright_tag_child1,stright_tag_child2),
            (POS_buf_top,bufleft_tag_child1,bufleft_tag_child2),
            (POS_st_top,POS_st_2ndtop,POS_st_3rdtop)
                            )
        
        context_features['word_val_feat'] = (
            (word_st_top,stright_word_val),
            (word_st_top,stleft_word_val),
            (word_buf_top,bufleft_word_val)
                        )
        
        context_features['tag_val_feat'] = (
            (POS_st_top,stright_word_val),
            (POS_st_top,stleft_word_val),
            (POS_buf_top,bufleft_word_val)
                       )
        
        context_features['distance_feat'] = (
            (word_st_top,distance),
            (word_buf_top,distance),
            (POS_st_top,distance),
            (POS_buf_top,distance),
            ('tag '+ POS_st_top + POS_buf_top,distance),
            ('word_ft ' + word_st_top + word_buf_top,distance)
        )
        
        
        for k,v in context_features.items():
            if k == 'word_val_feat':
                for (word,val) in v:
                    #print((word,val))
                    if word or val:
                        features[f'word = {word} val = {val}']=1
                        
            elif k == 'tag_val_feat':
                for (tag,val) in v:
                    #print((tag,val))
                    if tag or val:
                        features[f'tag = {tag} val = {val}']=1
                        
            elif k == 'distance_feat':
                for (word_ft,dist) in v:
                    #print((word_ft,dist))
                    if word_ft or dist:
                        features[f'{word_ft} distance = {dist}']=1

            
#             elif k == 'trigrams_features':
#                 for (ft1,ft2,ft3) in v:
#                     #print((ft1,ft2,ft3))
#                     if ft1 or ft2 or ft3:
#                         features[f'trigram = {ft1} {ft2} {ft3}']=1
                        
                        
#             elif k == 'bigram_features':
#                 for ft1,ft2 in v:
#                     if ft1 or ft2:
#                         features[f'biigram = {ft1} {ft2}']=1

#              if k == 'word_tag_pairs':
#                 for (word,tag) in v:
#                     #print((word,tag))
#                     if word or tag:
#                         features[f'word = {word} tag = {tag}']=1

                                                
        label = current_transtion
        
        return features,label

       
    def create_reverse_mappings(self,label_id,feature_id):
        self.reverse_labels = [0] * label_id # empty array of number of labels
        self.reverse_features = [0] * feature_id # empty array of number of features
        
        for feature in tqdm(self.feature_vocabulary):
            self.reverse_features[self.feature_vocabulary[feature]] = feature
        for label in tqdm(self.label_vocabulary):
            self.reverse_labels[self.label_vocabulary[label]] = label

        
    
    def convert_to_training_data(self,):
        
        label_id = 0
        feature_id = 0 
        
        feature_counts = defaultdict(int)
        total_features = len(self.features)
        
        print('Building Training Data...')
        
        for i in tqdm(range(total_features)):
            for feature in self.features[i]:
                feature_counts[feature] += 1
                
            if self.label_vocabulary.get(self.labels[i]) is None:
                self.label_vocabulary[self.labels[i]] = label_id
                label_id += 1
                
        for feature in tqdm(feature_counts):
            if feature_counts[ feature ] > 5 and self.feature_vocabulary.get(feature) is None:
                self.feature_vocabulary[ feature ] = feature_id
                feature_id += 1
        
        print('building cache')
        self.create_reverse_mappings(label_id,feature_id)
        
        self.max_features = feature_id
        x_train = sparse.lil_matrix((total_features,feature_id))
        y_train = list()
        
        for i in tqdm(range(total_features)):
            for feature in self.features[i]:
                
                if self.feature_vocabulary.get(feature) is not None:
                    f_count = self.feature_vocabulary[feature]
                    x_train[i,f_count] = 1
                
            y_train.append(self.label_vocabulary[self.labels[i]])
        
        return x_train,y_train

    
        
    def getChildren(self,state,transitions):
        
        num_words = len(state[0][0])
        dependencies = Parse(num_words)


        for i in range(1,len(state)):
            
            curr_buff = deepcopy(state[i][0])
            curr_stack = deepcopy(state[i][1])
            curr_arc = deepcopy(state[i][2])
            
            
            #print(transitions[i-1])
            #print(curr_buff)
            #print(curr_stack)
            #print(curr_arc)

            if transitions[i-1] == 'shift':
                #print('-'*50)
                continue
            
            elif transitions[i-1].startswith('left'):
                head = curr_arc[-1][1]
                child = curr_arc[-1][2]
                
                dependencies.add_arc(head,child)
                
            elif transitions[i-1].startswith('right'):
                head = curr_arc[-1][1]
                child = curr_arc[-1][2]
                
                dependencies.add_arc(head,child)
                
            #print(dependencies.heads)
            #print(dependencies.left_arc)
            #print(dependencies.right_arc)
            #print('-'*50)
            
        return dependencies
    

    def extract_line_tokens(self,line):
        line_id,word,stem_word,u_pos,x_pos = line[0],line[1],line[2],line[3],line[4]
        feat,head,dep_rel,dep,misc = line[5],line[6],line[7],line[8],line[9]
    
        return int(line_id),word,x_pos,int(head),dep_rel
                
    def build_oracles(self,):
        
        current_tokens = []
        tokens_dict = {}
        POS_tags = {}
        
        tokens_dict[0]= 'root'
        POS_tags[0]= 'root'
        
        for current_line in self.train_treebank:
    
            if len(current_line) < 2 : # useful fields
                
                if len(current_tokens) > 0 : #have found some tokens before
                    
                        
                    if self.check_projectivity(current_tokens) == True: #if current tree is projective
            
                        
                        configuration_state,gold_transitions = self.extract_configs_transitions(current_tokens)
                        
                        tree_dependencies = self.getChildren(configuration_state,gold_transitions)
                        
                        for i in range(len(configuration_state)):
                            #print(f'{configuration_state[i]}------{gold_transitions[i]}')
#                             features , labels = self.get_features_labels(configuration_state[i],gold_transitions[i],
#                                                                          tokens_dict,POS_tags)

                            
                            features , labels = self.extract_features(configuration_state[i],gold_transitions[i],
                                                  tree_dependencies,tokens_dict,POS_tags)

                            
                            self.features.append(features)
                            self.labels.append(labels)
                    

                    
                    current_tokens = []
                    tokens_dict = {}
                    POS_tags = {}
                    
                    tokens_dict[0]= 'root'
                    POS_tags[0]= 'root'
                    
                continue
                
            if current_line[0].startswith('#'):
                continue
            
            tok_id,word,x_pos,head_id,dep_rel = self.extract_line_tokens(current_line)
            current_tokens.append((tok_id,word,x_pos,head_id,dep_rel))
            tokens_dict[tok_id] = word
            POS_tags[tok_id] = x_pos 
            
            
       
        X_train,y_train = self.convert_to_training_data()
        
        print('finished')
        return X_train,y_train,self.features
    
    def get_model(self,model_name):
        
        model = None
        if model_name == 'lr_l2':
            model = LogisticRegression(verbose = 2,n_jobs = 40)
        
        elif model_name == 'lr_el_saga':
            model = LogisticRegression(penalty = 'elasticnet',verbose = 2,n_jobs = 4,solver = 'saga',l1_ratio = 0.25)

        elif model_name == 'svm_rbf':
            model = SVC(kernel = 'rbf', C=1.6)
        
        elif model_name == 'svm_poly':
            model = SVC(kernel = 'poly', C=1.5)
        
        elif model_name == 'sgd_l2':
            model = SGDClassifier(shuffle = False)
        
        elif model_name == 'sgd_el':
            model = SGDClassifier(penalty = 'elasticnet', shuffle=False)
        
        elif model_name == 'rf_gini':
            model = RandomForestClassifier(n_estimators = 552, criterion = 'gini', n_jobs = 4 )
        
        elif model_name == 'rf_ent':
            model = RandomForestClassifier(n_estimators = 552, criterion = 'entropy', n_jobs = 4 )
            
        elif model_name == 'pac':
            model = PassiveAggressiveClassifier(n_jobs = 4,vebose = 2)
        
        elif model_name == 'gnb':
            model = GaussianNB()
        
        elif model_name == 'bnb':
            model = BernoulliNB()
        
        elif model_name == 'lgb':
            model = LGBMClassifier()
            
        return model   

    def train(self,x_train,y_train,model_name = None):
        
        self.classifier = model_name
        
        model = self.get_model(model_name)
        
        model.fit(x_train,y_train)
        
        return model
    
    def action_to_tree(self,test_dependency_tree,prediction_probabs,test_buffer,test_stack,test_arcs):
        
        def is_action_valid(test_stack,test_buffer,action_taken):
            if action_taken == "shift" and len(test_buffer) > 0 :
                return True
            
            elif action_taken.startswith('left') and len(test_stack) > 1 and test_stack[-1] != 0: #0 is root
                return True 
            
            elif action_taken.startswith('right') and len(test_stack) > 1 and test_stack[-2] != 0: #0 is root
                return True 
            
            else:
                return False
            
            
        for label_id_prob in np.argsort(prediction_probabs, kind = 'quicksort')[0]:
            
            action_taken = self.reverse_labels[label_id_prob]
            
            if is_action_valid(test_stack,test_buffer,action_taken):
                
                if action_taken == "shift":
                    test_stack.append(test_buffer.pop())
                
                elif action_taken.startswith('left'):
                    arc_label = action_taken.split('_')[1]
                    test_dependency_tree[test_stack[-2]] = (test_stack[-1], arc_label)
                    test_stack.pop(-2)
                    
                elif action_taken.startswith('right'):
                    arc_label = action_taken.split('_')[1]
                    test_dependency_tree[test_stack[-1]] = (test_stack[-2], arc_label)
                    test_stack.pop()
                return
    
    def evaluate_oracles_and_predictions(self,test_tokens,model):
        
        test_tokens_dict = defaultdict()
        test_POS_tags = defaultdict()
        
        test_tokens_dict[0] = 'root'
        test_POS_tags[0] = 'root'
        
        test_heads = defaultdict()
        test_labels = defaultdict()
        test_heads[0] = 'root'
        
        test_buffer = list()
        
        test_stack = list()
        test_stack.append(0)
        
        test_arcs = list()
        
        
        
        for test_token in reversed(test_tokens):
            
            token_id,token_word,token_tag,token_head,token_label = test_token
            
            test_tokens_dict[token_id] = token_word
            test_POS_tags[token_id] = token_tag
            
            test_heads[token_id] = token_head
            test_labels[token_id] = token_label
            
            test_buffer.append(token_id)
            
        i = 0
        test_config_state,test_gold_transitions = self.extract_configs_transitions(test_tokens)     
        test_tree_dep = self.getChildren(test_config_state,test_gold_transitions)
        
        test_dependency_tree = defaultdict()
                
        while len(test_buffer) > 0 :
            
            if len(test_buffer) == 0  and len(test_stack)==0 : #nothing available to perform an action
                break
                
            if len(test_buffer) == 0  and len(test_stack)==1 and test_stack[0] == 0 : #nothing but root
                break
            
            current_config =  (test_buffer,test_stack,test_arcs)
                        
            test_features,_ = self.extract_features(current_config,None,
                                                  test_tree_dep,test_tokens_dict,test_POS_tags)
            
            x_test = sparse.lil_matrix((1,self.max_features))
            
            for feature in test_features:
                if self.feature_vocabulary.get(feature) is not None:
                    x_test[0,self.feature_vocabulary[feature]] = 1
                    
            prediction_probabs = -1 * model.predict_proba(x_test)
            
            self.action_to_tree(test_dependency_tree,prediction_probabs,test_buffer,test_stack,test_arcs)
            
        unlabelled_attachment_score = 0
        labelled_attachment_score = 0
            
        total_children = 0
        
        for child in test_dependency_tree:
                
    
            token_head,arc_label = test_dependency_tree[child]
        


            if token_head == test_heads[child]:
                unlabelled_attachment_score += 1
                    
                if arc_label == test_labels[child]:
                    labelled_attachment_score += 1
                
            total_children += 1
                
        return [unlabelled_attachment_score,labelled_attachment_score,total_children]
        
    
    def evaluate(self,test_treebank,model):
        
        if self.test_treebank is None:
            self.test_treebank = test_treebank
        
        test_tokens = [] #tokens in current line
        current_all_scores = []
        total_scores = np.zeros(3)
        
        i=0
        
        for current_line in tqdm(self.test_treebank):
            i+=1
            if len(current_line) < 2 :
                
                if len(test_tokens) > 0: # has seen tokens
                    #print(test_tokens)
                    if self.check_projectivity(test_tokens) == True:
                        
                            current_all_scores = self.evaluate_oracles_and_predictions(test_tokens,model)
                            total_scores += current_all_scores
                            
                            print(f'Total lines : {total_scores[2]} \n Unlabelled attachment Score {total_scores[0]/total_scores[2]} \n Labelled attachment Score {total_scores[1]/total_scores[2]}')
                            
                            
                    test_tokens = []
                continue
                
            if current_line[0].startswith('#'):
                continue
            
            tok_id,word,x_pos,head_id,dep_rel = self.extract_line_tokens(current_line)
            test_tokens.append((tok_id,word,x_pos,head_id,dep_rel))
        
        accuracy = f'Total lines : {total_scores[2]} \n Unlabelled attachment Score {total_scores[0]/total_scores[2]} \n Unlabelled attachment Score {total_scores[1]/total_scores[2]}'
        
        return accuracy

# %%
train_treebank = read_file(train_file_conllu)
test_treebank = read_file(val_file_conllu)

# %%
    

dp = DependencyParser(train_treebank)


# (deprel,i1,i2) --> {left : i1 is head,i2 is child}
x_train,y_train,f = dp.build_oracles()
# Out:
# Building Training Data...
# HBox(children=(FloatProgress(value=0.0, max=460986.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=394204.0), HTML(value='')))
# building cache
# HBox(children=(FloatProgress(value=0.0, max=94661.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=53.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=460986.0), HTML(value='')))
# finished

# %%
# %%time

model3 = dp.train(x_train,y_train,'lr_l2')
# Out:
# [Parallel(n_jobs=40)]: Using backend LokyBackend with 40 concurrent workers.
# Wall time: 3min 31s
# [Parallel(n_jobs=40)]: Done   1 out of   1 | elapsed:  3.5min finished

# %%
x_train
# Out:
# <460986x94661 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8816042 stored elements in LInked List format>

# %%
accuracy3 = dp.evaluate(test_treebank,model3)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=40194.0), HTML(value='')))
# Total lines : 22.0
#  Unlabelled attachment Score 0.8181818181818182
#  Labelled attachment Score 0.7727272727272727
# Total lines : 35.0
#  Unlabelled attachment Score 0.8285714285714286
#  Labelled attachment Score 0.7714285714285715
# Total lines : 52.0
#  Unlabelled attachment Score 0.8269230769230769
#  Labelled attachment Score 0.7884615384615384
# Total lines : 77.0
#  Unlabelled attachment Score 0.7792207792207793
#  Labelled attachment Score 0.7272727272727273
# Total lines : 87.0
#  Unlabelled attachment Score 0.7931034482758621
#  Labelled attachment Score 0.735632183908046
# Total lines : 87.0
#  Unlabelled attachment Score 0.7931034482758621
#  Labelled attachment Score 0.735632183908046
# Total lines : 99.0
#  Unlabelled attachment Score 0.8080808080808081
#  Labelled attachment Score 0.7575757575757576
# Total lines : 112.0
#  Unlabelled attachment Score 0.8303571428571429
#  Labelled attachment Score 0.7767857142857143
# Total lines : 118.0
#  Unlabelled attachment Score 0.8389830508474576
#  Labelled attachment Score 0.7796610169491526
# Total lines : 127.0
#  Unlabelled attachment Score 0.8346456692913385
#  Labelled attachment Score 0.7716535433070866
# Total lines : 138.0
#  Unlabelled attachment Score 0.8260869565217391
#  Labelled attachment Score 0.7608695652173914
# Total lines : 145.0
#  Unlabelled attachment Score 0.8275862068965517
#  Labelled attachment Score 0.7655172413793103
# Total lines : 154.0
#  Unlabelled attachment Score 0.8376623376623377
#  Labelled attachment Score 0.7727272727272727
# Total lines : 165.0
#  Unlabelled attachment Score 0.8363636363636363
#  Labelled attachment Score 0.7757575757575758
# Total lines : 173.0
#  Unlabelled attachment Score 0.838150289017341
#  Labelled attachment Score 0.7745664739884393
# Total lines : 189.0
#  Unlabelled attachment Score 0.8412698412698413
#  Labelled attachment Score 0.7671957671957672
# Total lines : 198.0
#  Unlabelled attachment Score 0.8484848484848485
#  Labelled attachment Score 0.7727272727272727
# Total lines : 208.0
#  Unlabelled attachment Score 0.8461538461538461
#  Labelled attachment Score 0.7740384615384616
# Total lines : 221.0
#  Unlabelled attachment Score 0.8371040723981901
#  Labelled attachment Score 0.7692307692307693
# Total lines : 234.0
#  Unlabelled attachment Score 0.8461538461538461
#  Labelled attachment Score 0.7735042735042735
# Total lines : 242.0
#  Unlabelled attachment Score 0.8512396694214877
#  Labelled attachment Score 0.7768595041322314
# Total lines : 247.0
#  Unlabelled attachment Score 0.854251012145749
#  Labelled attachment Score 0.7773279352226721
# Total lines : 260.0
#  Unlabelled attachment Score 0.8461538461538461
#  Labelled attachment Score 0.7730769230769231
# Total lines : 263.0
#  Unlabelled attachment Score 0.8479087452471483
#  Labelled attachment Score 0.7718631178707225
# Total lines : 279.0
#  Unlabelled attachment Score 0.8422939068100358
#  Labelled attachment Score 0.7670250896057348
# Total lines : 291.0
#  Unlabelled attachment Score 0.8384879725085911
#  Labelled attachment Score 0.7628865979381443
# Total lines : 301.0
#  Unlabelled attachment Score 0.840531561461794
#  Labelled attachment Score 0.7641196013289037
# Total lines : 313.0
#  Unlabelled attachment Score 0.8466453674121406
#  Labelled attachment Score 0.7667731629392971
# Total lines : 328.0
#  Unlabelled attachment Score 0.8536585365853658
#  Labelled attachment Score 0.7652439024390244
# Total lines : 342.0
#  Unlabelled attachment Score 0.8538011695906432
#  Labelled attachment Score 0.7660818713450293
# Total lines : 352.0
#  Unlabelled attachment Score 0.8579545454545454
#  Labelled attachment Score 0.7727272727272727
# Total lines : 365.0
#  Unlabelled attachment Score 0.8547945205479452
#  Labelled attachment Score 0.7698630136986301
# Total lines : 381.0
#  Unlabelled attachment Score 0.8582677165354331
#  Labelled attachment Score 0.7742782152230971
# Total lines : 394.0
#  Unlabelled attachment Score 0.8604060913705583
#  Labelled attachment Score 0.7766497461928934
# Total lines : 400.0
#  Unlabelled attachment Score 0.86
#  Labelled attachment Score 0.7775
# Total lines : 421.0
#  Unlabelled attachment Score 0.8456057007125891
#  Labelled attachment Score 0.7648456057007126
# Total lines : 435.0
#  Unlabelled attachment Score 0.8436781609195402
#  Labelled attachment Score 0.7632183908045977
# Total lines : 446.0
#  Unlabelled attachment Score 0.8430493273542601
#  Labelled attachment Score 0.7645739910313901
# Total lines : 454.0
#  Unlabelled attachment Score 0.8436123348017621
#  Labelled attachment Score 0.76431718061674
# Total lines : 459.0
#  Unlabelled attachment Score 0.8453159041394336
#  Labelled attachment Score 0.7647058823529411
# Total lines : 468.0
#  Unlabelled attachment Score 0.844017094017094
#  Labelled attachment Score 0.7628205128205128
# Total lines : 470.0
#  Unlabelled attachment Score 0.8446808510638298
#  Labelled attachment Score 0.7638297872340426
# Total lines : 485.0
#  Unlabelled attachment Score 0.843298969072165
#  Labelled attachment Score 0.7649484536082474
# Total lines : 495.0
#  Unlabelled attachment Score 0.8464646464646465
#  Labelled attachment Score 0.7696969696969697
# Total lines : 504.0
#  Unlabelled attachment Score 0.8492063492063492
#  Labelled attachment Score 0.7738095238095238
# Total lines : 516.0
#  Unlabelled attachment Score 0.8488372093023255
#  Labelled attachment Score 0.7751937984496124
# Total lines : 524.0
#  Unlabelled attachment Score 0.8492366412213741
#  Labelled attachment Score 0.7748091603053435
# Total lines : 529.0
#  Unlabelled attachment Score 0.8506616257088847
#  Labelled attachment Score 0.775047258979206
# Total lines : 538.0
#  Unlabelled attachment Score 0.8494423791821561
#  Labelled attachment Score 0.7732342007434945
# Total lines : 548.0
#  Unlabelled attachment Score 0.8521897810218978
#  Labelled attachment Score 0.7737226277372263
# Total lines : 560.0
#  Unlabelled attachment Score 0.8517857142857143
#  Labelled attachment Score 0.7678571428571429
# Total lines : 573.0
#  Unlabelled attachment Score 0.849912739965096
#  Labelled attachment Score 0.7661431064572426
# Total lines : 591.0
#  Unlabelled attachment Score 0.8510998307952623
#  Labelled attachment Score 0.7681895093062606
# Total lines : 603.0
#  Unlabelled attachment Score 0.8507462686567164
#  Labelled attachment Score 0.7645107794361525
# Total lines : 614.0
#  Unlabelled attachment Score 0.8517915309446255
#  Labelled attachment Score 0.7671009771986971
# Total lines : 619.0
#  Unlabelled attachment Score 0.8529886914378029
#  Labelled attachment Score 0.7689822294022617
# Total lines : 642.0
#  Unlabelled attachment Score 0.8457943925233645
#  Labelled attachment Score 0.764797507788162
# Total lines : 656.0
#  Unlabelled attachment Score 0.8475609756097561
#  Labelled attachment Score 0.7682926829268293
# Total lines : 671.0
#  Unlabelled attachment Score 0.8390461997019374
#  Labelled attachment Score 0.7615499254843517
# Total lines : 702.0
#  Unlabelled attachment Score 0.8347578347578347
#  Labelled attachment Score 0.7549857549857549
# Total lines : 712.0
#  Unlabelled attachment Score 0.8328651685393258
#  Labelled attachment Score 0.7542134831460674
# Total lines : 729.0
#  Unlabelled attachment Score 0.8353909465020576
#  Labelled attachment Score 0.7585733882030178
# Total lines : 735.0
#  Unlabelled attachment Score 0.8353741496598639
#  Labelled attachment Score 0.7591836734693878
# Total lines : 736.0
#  Unlabelled attachment Score 0.8355978260869565
#  Labelled attachment Score 0.7595108695652174
# Total lines : 750.0
#  Unlabelled attachment Score 0.8346666666666667
#  Labelled attachment Score 0.7586666666666667
# Total lines : 761.0
#  Unlabelled attachment Score 0.8370565045992115
#  Labelled attachment Score 0.7608409986859396
# Total lines : 774.0
#  Unlabelled attachment Score 0.838501291989664
#  Labelled attachment Score 0.7596899224806202
# Total lines : 788.0
#  Unlabelled attachment Score 0.8388324873096447
#  Labelled attachment Score 0.7614213197969543
# Total lines : 804.0
#  Unlabelled attachment Score 0.8370646766169154
#  Labelled attachment Score 0.7611940298507462
# Total lines : 827.0
#  Unlabelled attachment Score 0.8343409915356711
#  Labelled attachment Score 0.7581620314389359
# Total lines : 828.0
#  Unlabelled attachment Score 0.8345410628019324
#  Labelled attachment Score 0.7584541062801933
# Total lines : 841.0
#  Unlabelled attachment Score 0.8335315101070154
#  Labelled attachment Score 0.7574316290130797
# Total lines : 864.0
#  Unlabelled attachment Score 0.8275462962962963
#  Labelled attachment Score 0.75
# Total lines : 877.0
#  Unlabelled attachment Score 0.8289623717217788
#  Labelled attachment Score 0.750285062713797
# Total lines : 885.0
#  Unlabelled attachment Score 0.8305084745762712
#  Labelled attachment Score 0.751412429378531
# Total lines : 892.0
#  Unlabelled attachment Score 0.827354260089686
#  Labelled attachment Score 0.7488789237668162
# Total lines : 903.0
#  Unlabelled attachment Score 0.8272425249169435
#  Labelled attachment Score 0.7497231450719822
# Total lines : 913.0
#  Unlabelled attachment Score 0.8291347207009858
#  Labelled attachment Score 0.7524644030668127
# Total lines : 927.0
#  Unlabelled attachment Score 0.8306364617044228
#  Labelled attachment Score 0.7529665587918015
# Total lines : 943.0
#  Unlabelled attachment Score 0.8303287380699894
#  Labelled attachment Score 0.750795334040297
# Total lines : 947.0
#  Unlabelled attachment Score 0.8310454065469906
#  Labelled attachment Score 0.750791974656811
# Total lines : 954.0
#  Unlabelled attachment Score 0.8301886792452831
#  Labelled attachment Score 0.749475890985325
# Total lines : 966.0
#  Unlabelled attachment Score 0.8291925465838509
#  Labelled attachment Score 0.7494824016563147
# Total lines : 976.0
#  Unlabelled attachment Score 0.8288934426229508
#  Labelled attachment Score 0.75
# Total lines : 1008.0
#  Unlabelled attachment Score 0.8214285714285714
#  Labelled attachment Score 0.7430555555555556
# Total lines : 1037.0
#  Unlabelled attachment Score 0.8167791706846673
#  Labelled attachment Score 0.7396335583413693
# Total lines : 1056.0
#  Unlabelled attachment Score 0.8181818181818182
#  Labelled attachment Score 0.7414772727272727
# Total lines : 1061.0
#  Unlabelled attachment Score 0.8180961357210179
#  Labelled attachment Score 0.7417530631479736
# Total lines : 1069.0
#  Unlabelled attachment Score 0.8194574368568756
#  Labelled attachment Score 0.7418147801683816
# Total lines : 1090.0
#  Unlabelled attachment Score 0.8201834862385321
#  Labelled attachment Score 0.7412844036697248
# Total lines : 1104.0
#  Unlabelled attachment Score 0.8170289855072463
#  Labelled attachment Score 0.7364130434782609
# Total lines : 1109.0
#  Unlabelled attachment Score 0.8160504959422904
#  Labelled attachment Score 0.7357980162308386
# Total lines : 1117.0
#  Unlabelled attachment Score 0.8164726947179947
#  Labelled attachment Score 0.7358997314234557
# Total lines : 1128.0
#  Unlabelled attachment Score 0.8173758865248227
#  Labelled attachment Score 0.7367021276595744
# Total lines : 1140.0
#  Unlabelled attachment Score 0.8192982456140351
#  Labelled attachment Score 0.7394736842105263
# Total lines : 1148.0
#  Unlabelled attachment Score 0.8205574912891986
#  Labelled attachment Score 0.740418118466899
# Total lines : 1154.0
#  Unlabelled attachment Score 0.8206239168110918
#  Labelled attachment Score 0.7400346620450606
# Total lines : 1160.0
#  Unlabelled attachment Score 0.821551724137931
#  Labelled attachment Score 0.7405172413793103
# Total lines : 1165.0
#  Unlabelled attachment Score 0.8223175965665236
#  Labelled attachment Score 0.7416309012875536
# Total lines : 1174.0
#  Unlabelled attachment Score 0.8219761499148212
#  Labelled attachment Score 0.7410562180579217
# Total lines : 1195.0
#  Unlabelled attachment Score 0.8225941422594142
#  Labelled attachment Score 0.7430962343096235
# Total lines : 1209.0
#  Unlabelled attachment Score 0.8229942100909843
#  Labelled attachment Score 0.7427626137303557
# Total lines : 1226.0
#  Unlabelled attachment Score 0.8238172920065253
#  Labelled attachment Score 0.7438825448613376
# Total lines : 1247.0
#  Unlabelled attachment Score 0.8251804330392943
#  Labelled attachment Score 0.7457898957497995
# Total lines : 1283.0
#  Unlabelled attachment Score 0.8246297739672642
#  Labelled attachment Score 0.7459080280592362
# Total lines : 1289.0
#  Unlabelled attachment Score 0.8238944918541505
#  Labelled attachment Score 0.7439875872769589
# Total lines : 1294.0
#  Unlabelled attachment Score 0.8238021638330757
#  Labelled attachment Score 0.7442040185471407
# Total lines : 1302.0
#  Unlabelled attachment Score 0.8248847926267281
#  Labelled attachment Score 0.7427035330261137
# Total lines : 1313.0
#  Unlabelled attachment Score 0.824067022086824
#  Labelled attachment Score 0.741051028179741
# Total lines : 1339.0
#  Unlabelled attachment Score 0.8252427184466019
#  Labelled attachment Score 0.7415982076176251
# Total lines : 1368.0
#  Unlabelled attachment Score 0.8289473684210527
#  Labelled attachment Score 0.7448830409356725
# Total lines : 1374.0
#  Unlabelled attachment Score 0.8296943231441049
#  Labelled attachment Score 0.7459970887918487
# Total lines : 1400.0
#  Unlabelled attachment Score 0.8307142857142857
#  Labelled attachment Score 0.7464285714285714
# Total lines : 1404.0
#  Unlabelled attachment Score 0.8311965811965812
#  Labelled attachment Score 0.7471509971509972
# Total lines : 1418.0
#  Unlabelled attachment Score 0.8321579689703809
#  Labelled attachment Score 0.7489421720733427
# Total lines : 1438.0
#  Unlabelled attachment Score 0.8331015299026425
#  Labelled attachment Score 0.7489568845618915
# Total lines : 1455.0
#  Unlabelled attachment Score 0.8329896907216495
#  Labelled attachment Score 0.7498281786941581
# Total lines : 1462.0
#  Unlabelled attachment Score 0.8337893296853626
#  Labelled attachment Score 0.7496580027359782
# Total lines : 1478.0
#  Unlabelled attachment Score 0.8355886332882273
#  Labelled attachment Score 0.7503382949932341
# Total lines : 1499.0
#  Unlabelled attachment Score 0.8365577051367579
#  Labelled attachment Score 0.7505003335557038
# Total lines : 1519.0
#  Unlabelled attachment Score 0.8367346938775511
#  Labelled attachment Score 0.749835418038183
# Total lines : 1534.0
#  Unlabelled attachment Score 0.8370273794002607
#  Labelled attachment Score 0.7503259452411994
# Total lines : 1557.0
#  Unlabelled attachment Score 0.838150289017341
#  Labelled attachment Score 0.7514450867052023
# Total lines : 1592.0
#  Unlabelled attachment Score 0.8347989949748744
#  Labelled attachment Score 0.7493718592964824
# Total lines : 1626.0
#  Unlabelled attachment Score 0.8357933579335793
#  Labelled attachment Score 0.7509225092250923
# Total lines : 1647.0
#  Unlabelled attachment Score 0.835458409228901
#  Labelled attachment Score 0.7510625379477839
# Total lines : 1664.0
#  Unlabelled attachment Score 0.8365384615384616
#  Labelled attachment Score 0.7518028846153846
# Total lines : 1677.0
#  Unlabelled attachment Score 0.836612999403697
#  Labelled attachment Score 0.751937984496124
# Total lines : 1705.0
#  Unlabelled attachment Score 0.8363636363636363
#  Labelled attachment Score 0.7513196480938417
# Total lines : 1732.0
#  Unlabelled attachment Score 0.836027713625866
#  Labelled attachment Score 0.75
# Total lines : 1755.0
#  Unlabelled attachment Score 0.837037037037037
#  Labelled attachment Score 0.7504273504273504
# Total lines : 1769.0
#  Unlabelled attachment Score 0.8366308648954212
#  Labelled attachment Score 0.749576031656303
# Total lines : 1786.0
#  Unlabelled attachment Score 0.8376259798432251
#  Labelled attachment Score 0.7502799552071668
# Total lines : 1801.0
#  Unlabelled attachment Score 0.8384230982787341
#  Labelled attachment Score 0.7512493059411438
# Total lines : 1810.0
#  Unlabelled attachment Score 0.8392265193370165
#  Labelled attachment Score 0.7519337016574585
# Total lines : 1847.0
#  Unlabelled attachment Score 0.8375744450460205
#  Labelled attachment Score 0.7520303194369248
# Total lines : 1863.0
#  Unlabelled attachment Score 0.8373590982286635
#  Labelled attachment Score 0.7520128824476651
# Total lines : 1872.0
#  Unlabelled attachment Score 0.8381410256410257
#  Labelled attachment Score 0.7521367521367521
# Total lines : 1882.0
#  Unlabelled attachment Score 0.8390010626992561
#  Labelled attachment Score 0.7529224229543039
# Total lines : 1902.0
#  Unlabelled attachment Score 0.8401682439537329
#  Labelled attachment Score 0.7544689800210305
# Total lines : 1914.0
#  Unlabelled attachment Score 0.8380355276907001
#  Labelled attachment Score 0.7528735632183908
# Total lines : 1928.0
#  Unlabelled attachment Score 0.8392116182572614
#  Labelled attachment Score 0.7546680497925311
# Total lines : 1950.0
#  Unlabelled attachment Score 0.84
#  Labelled attachment Score 0.7553846153846154
# Total lines : 1972.0
#  Unlabelled attachment Score 0.8387423935091278
#  Labelled attachment Score 0.7545638945233266
# Total lines : 2001.0
#  Unlabelled attachment Score 0.8390804597701149
#  Labelled attachment Score 0.7551224387806097
# Total lines : 2008.0
#  Unlabelled attachment Score 0.8396414342629482
#  Labelled attachment Score 0.7554780876494024
# Total lines : 2033.0
#  Unlabelled attachment Score 0.839153959665519
#  Labelled attachment Score 0.7555336940482046
# Total lines : 2046.0
#  Unlabelled attachment Score 0.8401759530791789
#  Labelled attachment Score 0.7561094819159335
# Total lines : 2066.0
#  Unlabelled attachment Score 0.8402710551790901
#  Labelled attachment Score 0.7560503388189739
# Total lines : 2076.0
#  Unlabelled attachment Score 0.8386319845857418
#  Labelled attachment Score 0.7548169556840078
# Total lines : 2088.0
#  Unlabelled attachment Score 0.8395593869731801
#  Labelled attachment Score 0.7547892720306514
# Total lines : 2100.0
#  Unlabelled attachment Score 0.84
#  Labelled attachment Score 0.7542857142857143
# Total lines : 2118.0
#  Unlabelled attachment Score 0.839943342776204
#  Labelled attachment Score 0.7535410764872521
# Total lines : 2142.0
#  Unlabelled attachment Score 0.8394024276377218
#  Labelled attachment Score 0.7530345471521942
# Total lines : 2169.0
#  Unlabelled attachment Score 0.8395573997233748
#  Labelled attachment Score 0.7524204702627939
# Total lines : 2177.0
#  Unlabelled attachment Score 0.8392282958199357
#  Labelled attachment Score 0.752411575562701
# Total lines : 2194.0
#  Unlabelled attachment Score 0.8400182315405652
#  Labelled attachment Score 0.7534184138559709
# Total lines : 2210.0
#  Unlabelled attachment Score 0.8398190045248869
#  Labelled attachment Score 0.7538461538461538
# Total lines : 2246.0
#  Unlabelled attachment Score 0.838379341050757
#  Labelled attachment Score 0.7533392698130009
# Total lines : 2269.0
#  Unlabelled attachment Score 0.8382547377699427
#  Labelled attachment Score 0.753195240193918
# Total lines : 2286.0
#  Unlabelled attachment Score 0.8385826771653543
#  Labelled attachment Score 0.7537182852143482
# Total lines : 2300.0
#  Unlabelled attachment Score 0.8386956521739131
#  Labelled attachment Score 0.7543478260869565
# Total lines : 2314.0
#  Unlabelled attachment Score 0.8388072601555747
#  Labelled attachment Score 0.7545375972342264
# Total lines : 2338.0
#  Unlabelled attachment Score 0.8400342172797263
#  Labelled attachment Score 0.7553464499572284
# Total lines : 2364.0
#  Unlabelled attachment Score 0.8396785109983079
#  Labelled attachment Score 0.7554991539763113
# Total lines : 2394.0
#  Unlabelled attachment Score 0.8404344193817878
#  Labelled attachment Score 0.7556390977443609
# Total lines : 2422.0
#  Unlabelled attachment Score 0.8389760528488852
#  Labelled attachment Score 0.7543352601156069
# Total lines : 2436.0
#  Unlabelled attachment Score 0.8399014778325123
#  Labelled attachment Score 0.7545155993431856
# Total lines : 2454.0
#  Unlabelled attachment Score 0.8398533007334963
#  Labelled attachment Score 0.7546862265688672
# Total lines : 2465.0
#  Unlabelled attachment Score 0.8405679513184584
#  Labelled attachment Score 0.7545638945233266
# Total lines : 2472.0
#  Unlabelled attachment Score 0.8410194174757282
#  Labelled attachment Score 0.7548543689320388
# Total lines : 2493.0
#  Unlabelled attachment Score 0.8419574809466506
#  Labelled attachment Score 0.7557160048134778
# Total lines : 2517.0
#  Unlabelled attachment Score 0.8414779499404053
#  Labelled attachment Score 0.7556615017878426
# Total lines : 2529.0
#  Unlabelled attachment Score 0.8422301304863582
#  Labelled attachment Score 0.7568208778173191
# Total lines : 2536.0
#  Unlabelled attachment Score 0.8426656151419558
#  Labelled attachment Score 0.7567034700315457
# Total lines : 2561.0
#  Unlabelled attachment Score 0.8414681764935572
#  Labelled attachment Score 0.7551737602499023
# Total lines : 2588.0
#  Unlabelled attachment Score 0.8423493044822257
#  Labelled attachment Score 0.7557959814528593
# Total lines : 2594.0
#  Unlabelled attachment Score 0.8427139552814187
#  Labelled attachment Score 0.7555898226676947
# Total lines : 2613.0
#  Unlabelled attachment Score 0.8427095292766934
#  Labelled attachment Score 0.7554535017221584
# Total lines : 2640.0
#  Unlabelled attachment Score 0.843939393939394
#  Labelled attachment Score 0.7549242424242424
# Total lines : 2654.0
#  Unlabelled attachment Score 0.8432554634513941
#  Labelled attachment Score 0.753956292388847
# Total lines : 2687.0
#  Unlabelled attachment Score 0.8425753628582062
#  Labelled attachment Score 0.7532564197990324
# Total lines : 2706.0
#  Unlabelled attachment Score 0.8433111603843311
#  Labelled attachment Score 0.753880266075388
# Total lines : 2731.0
#  Unlabelled attachment Score 0.8432808495056756
#  Labelled attachment Score 0.7543024533138045
# Total lines : 2744.0
#  Unlabelled attachment Score 0.8436588921282799
#  Labelled attachment Score 0.7540087463556852
# Total lines : 2769.0
#  Unlabelled attachment Score 0.8447092813289996
#  Labelled attachment Score 0.7555074033947273
# Total lines : 2779.0
#  Unlabelled attachment Score 0.84454839870457
#  Labelled attachment Score 0.7556675062972292
# Total lines : 2801.0
#  Unlabelled attachment Score 0.8432702606212067
#  Labelled attachment Score 0.7543734380578365
# Total lines : 2829.0
#  Unlabelled attachment Score 0.8437610463061153
#  Labelled attachment Score 0.7557440791799223
# Total lines : 2841.0
#  Unlabelled attachment Score 0.8437170010559663
#  Labelled attachment Score 0.7557198169658571
# Total lines : 2869.0
#  Unlabelled attachment Score 0.8452422446845591
#  Labelled attachment Score 0.756709654932032
# Total lines : 2885.0
#  Unlabelled attachment Score 0.8450606585788561
#  Labelled attachment Score 0.7563258232235702
# Total lines : 2903.0
#  Unlabelled attachment Score 0.843954529796762
#  Labelled attachment Score 0.7554254219772649
# Total lines : 2927.0
#  Unlabelled attachment Score 0.8428425008541168
#  Labelled attachment Score 0.7546976426375128
# Total lines : 2941.0
#  Unlabelled attachment Score 0.842570554233254
#  Labelled attachment Score 0.7541652499149949
# Total lines : 2957.0
#  Unlabelled attachment Score 0.8430842069665201
#  Labelled attachment Score 0.7548190733851877
# Total lines : 2979.0
#  Unlabelled attachment Score 0.8435716683450822
#  Labelled attachment Score 0.7546156428331655
# Total lines : 3000.0
#  Unlabelled attachment Score 0.8443333333333334
#  Labelled attachment Score 0.755
# Total lines : 3024.0
#  Unlabelled attachment Score 0.8442460317460317
#  Labelled attachment Score 0.7552910052910053
# Total lines : 3038.0
#  Unlabelled attachment Score 0.8439763001974984
#  Labelled attachment Score 0.7547728768926926
# Total lines : 3054.0
#  Unlabelled attachment Score 0.843811394891945
#  Labelled attachment Score 0.7544204322200393
# Total lines : 3070.0
#  Unlabelled attachment Score 0.8433224755700326
#  Labelled attachment Score 0.7537459283387622
# Total lines : 3087.0
#  Unlabelled attachment Score 0.843213475866537
#  Labelled attachment Score 0.7538062844185294
# Total lines : 3113.0
#  Unlabelled attachment Score 0.8429168005139737
#  Labelled attachment Score 0.7542563443623514
# Total lines : 3129.0
#  Unlabelled attachment Score 0.8437200383509108
#  Labelled attachment Score 0.7551933525087887
# Total lines : 3141.0
#  Unlabelled attachment Score 0.8433619866284623
#  Labelled attachment Score 0.7548551416746259
# Total lines : 3154.0
#  Unlabelled attachment Score 0.844007609384908
#  Labelled attachment Score 0.7549143944197844
# Total lines : 3160.0
#  Unlabelled attachment Score 0.8443037974683544
#  Labelled attachment Score 0.7553797468354431
# Total lines : 3173.0
#  Unlabelled attachment Score 0.8449416955562559
#  Labelled attachment Score 0.7560668137409392
# Total lines : 3203.0
#  Unlabelled attachment Score 0.8442085544801748
#  Labelled attachment Score 0.7558538869809553
# Total lines : 3217.0
#  Unlabelled attachment Score 0.8442648430214486
#  Labelled attachment Score 0.756294684488654
# Total lines : 3238.0
#  Unlabelled attachment Score 0.8437306979617047
#  Labelled attachment Score 0.75633106856084
# Total lines : 3255.0
#  Unlabelled attachment Score 0.8427035330261137
#  Labelled attachment Score 0.7554531490015362
# Total lines : 3264.0
#  Unlabelled attachment Score 0.8428308823529411
#  Labelled attachment Score 0.7555147058823529
# Total lines : 3285.0
#  Unlabelled attachment Score 0.8429223744292238
#  Labelled attachment Score 0.7552511415525114
# Total lines : 3297.0
#  Unlabelled attachment Score 0.843190779496512
#  Labelled attachment Score 0.7555353351531695
# Total lines : 3306.0
#  Unlabelled attachment Score 0.8433151845130067
#  Labelled attachment Score 0.7558983666061706
# Total lines : 3343.0
#  Unlabelled attachment Score 0.8432545617708644
#  Labelled attachment Score 0.7538139395752318
# Total lines : 3357.0
#  Unlabelled attachment Score 0.8430145963658028
#  Labelled attachment Score 0.7530533214179327
# Total lines : 3372.0
#  Unlabelled attachment Score 0.8431198102016607
#  Labelled attachment Score 0.7529655990510083
# Total lines : 3381.0
#  Unlabelled attachment Score 0.8432416444838805
#  Labelled attachment Score 0.7527358769594794
# Total lines : 3390.0
#  Unlabelled attachment Score 0.8433628318584071
#  Labelled attachment Score 0.752802359882006
# Total lines : 3404.0
#  Unlabelled attachment Score 0.8440070505287897
#  Labelled attachment Score 0.7529377203290247
# Total lines : 3427.0
#  Unlabelled attachment Score 0.8447621826670557
#  Labelled attachment Score 0.7531368543915962
# Total lines : 3439.0
#  Unlabelled attachment Score 0.8450130851991858
#  Labelled attachment Score 0.753416690898517
# Total lines : 3452.0
#  Unlabelled attachment Score 0.8455967555040557
#  Labelled attachment Score 0.7540556199304751
# Total lines : 3462.0
#  Unlabelled attachment Score 0.8460427498555748
#  Labelled attachment Score 0.7544771808203351
# Total lines : 3470.0
#  Unlabelled attachment Score 0.8463976945244956
#  Labelled attachment Score 0.7544668587896254
# Total lines : 3475.0
#  Unlabelled attachment Score 0.8463309352517986
#  Labelled attachment Score 0.7542446043165467
# Total lines : 3481.0
#  Unlabelled attachment Score 0.8463085320310255
#  Labelled attachment Score 0.7538063774777363
# Total lines : 3506.0
#  Unlabelled attachment Score 0.8465487735310896
#  Labelled attachment Score 0.7544209925841415
# Total lines : 3525.0
#  Unlabelled attachment Score 0.8462411347517731
#  Labelled attachment Score 0.7543262411347518
# Total lines : 3535.0
#  Unlabelled attachment Score 0.8463932107496464
#  Labelled attachment Score 0.7544554455445545
# Total lines : 3571.0
#  Unlabelled attachment Score 0.8465415849901988
#  Labelled attachment Score 0.7546905628675441
# Total lines : 3591.0
#  Unlabelled attachment Score 0.8471177944862155
#  Labelled attachment Score 0.7549429128376497
# Total lines : 3599.0
#  Unlabelled attachment Score 0.847457627118644
#  Labelled attachment Score 0.7554876354542929
# Total lines : 3610.0
#  Unlabelled attachment Score 0.8479224376731302
#  Labelled attachment Score 0.7562326869806094
# Total lines : 3619.0
#  Unlabelled attachment Score 0.8480243161094225
#  Labelled attachment Score 0.7565625863498204
# Total lines : 3637.0
#  Unlabelled attachment Score 0.8482265603519384
#  Labelled attachment Score 0.7572174869397855
# Total lines : 3646.0
#  Unlabelled attachment Score 0.8483269336258914
#  Labelled attachment Score 0.7572682391662096
# Total lines : 3658.0
#  Unlabelled attachment Score 0.8482777474029525
#  Labelled attachment Score 0.7572443958447239
# Total lines : 3680.0
#  Unlabelled attachment Score 0.8486413043478261
#  Labelled attachment Score 0.7573369565217392
# Total lines : 3700.0
#  Unlabelled attachment Score 0.8481081081081081
#  Labelled attachment Score 0.7567567567567568
# Total lines : 3709.0
#  Unlabelled attachment Score 0.8479374494472903
#  Labelled attachment Score 0.7568077648961984
# Total lines : 3726.0
#  Unlabelled attachment Score 0.8483628556092324
#  Labelled attachment Score 0.7571121846484166
# Total lines : 3737.0
#  Unlabelled attachment Score 0.8485416109178485
#  Labelled attachment Score 0.7572919454107573
# Total lines : 3779.0
#  Unlabelled attachment Score 0.8478433448002117
#  Labelled attachment Score 0.7576078327599894
# Total lines : 3790.0
#  Unlabelled attachment Score 0.8480211081794196
#  Labelled attachment Score 0.7575197889182058
# Total lines : 3817.0
#  Unlabelled attachment Score 0.8472622478386167
#  Labelled attachment Score 0.7571391144878177
# Total lines : 3824.0
#  Unlabelled attachment Score 0.8470188284518828
#  Labelled attachment Score 0.757060669456067
# Total lines : 3842.0
#  Unlabelled attachment Score 0.846954711087975
#  Labelled attachment Score 0.7571577303487766
# Total lines : 3869.0
#  Unlabelled attachment Score 0.8475058154561902
#  Labelled attachment Score 0.7575600930472991
# Total lines : 3880.0
#  Unlabelled attachment Score 0.847680412371134
#  Labelled attachment Score 0.7577319587628866
# Total lines : 3916.0
#  Unlabelled attachment Score 0.8480592441266599
#  Labelled attachment Score 0.758682328907048
# Total lines : 3942.0
#  Unlabelled attachment Score 0.8475393201420599
#  Labelled attachment Score 0.7584982242516489
# Total lines : 3962.0
#  Unlabelled attachment Score 0.8478041393235739
#  Labelled attachment Score 0.7589601211509339
# Total lines : 3973.0
#  Unlabelled attachment Score 0.8479738233073244
#  Labelled attachment Score 0.7591240875912408
# Total lines : 4002.0
#  Unlabelled attachment Score 0.847576211894053
#  Labelled attachment Score 0.7588705647176411
# Total lines : 4015.0
#  Unlabelled attachment Score 0.8478206724782067
#  Labelled attachment Score 0.7589041095890411
# Total lines : 4050.0
#  Unlabelled attachment Score 0.8479012345679012
#  Labelled attachment Score 0.7595061728395062
# Total lines : 4065.0
#  Unlabelled attachment Score 0.8484624846248463
#  Labelled attachment Score 0.7599015990159902
# Total lines : 4096.0
#  Unlabelled attachment Score 0.848876953125
#  Labelled attachment Score 0.76025390625
# Total lines : 4117.0
#  Unlabelled attachment Score 0.8484333252368229
#  Labelled attachment Score 0.7597765363128491
# Total lines : 4143.0
#  Unlabelled attachment Score 0.8489017620082067
#  Labelled attachment Score 0.759835867728699
# Total lines : 4176.0
#  Unlabelled attachment Score 0.8484195402298851
#  Labelled attachment Score 0.7595785440613027
# Total lines : 4207.0
#  Unlabelled attachment Score 0.8483479914428333
#  Labelled attachment Score 0.7599239362966485
# Total lines : 4242.0
#  Unlabelled attachment Score 0.8486562942008486
#  Labelled attachment Score 0.7602545968882602
# Total lines : 4293.0
#  Unlabelled attachment Score 0.8490566037735849
#  Labelled attachment Score 0.7607733519683205
# Total lines : 4319.0
#  Unlabelled attachment Score 0.8485760592729799
#  Labelled attachment Score 0.7603611947210003
# Total lines : 4328.0
#  Unlabelled attachment Score 0.8486598890942699
#  Labelled attachment Score 0.7603974121996303
# Total lines : 4348.0
#  Unlabelled attachment Score 0.8491260349586016
#  Labelled attachment Score 0.7608095676172953
# Total lines : 4379.0
#  Unlabelled attachment Score 0.8492806576844029
#  Labelled attachment Score 0.7609043160538936
# Total lines : 4394.0
#  Unlabelled attachment Score 0.8495675921711424
#  Labelled attachment Score 0.760127446517979
# Total lines : 4403.0
#  Unlabelled attachment Score 0.8496479672950261
#  Labelled attachment Score 0.7599364069952306
# Total lines : 4425.0
#  Unlabelled attachment Score 0.8499435028248588
#  Labelled attachment Score 0.7604519774011299
# Total lines : 4435.0
#  Unlabelled attachment Score 0.8498308906426155
#  Labelled attachment Score 0.7605411499436302
# Total lines : 4449.0
#  Unlabelled attachment Score 0.8498538997527534
#  Labelled attachment Score 0.7608451337379186
# Total lines : 4473.0
#  Unlabelled attachment Score 0.8497652582159625
#  Labelled attachment Score 0.7605633802816901
# Total lines : 4486.0
#  Unlabelled attachment Score 0.8497547926883638
#  Labelled attachment Score 0.7605884975479269
# Total lines : 4517.0
#  Unlabelled attachment Score 0.8499003763559885
#  Labelled attachment Score 0.7604604826212088
# Total lines : 4526.0
#  Unlabelled attachment Score 0.8497569597878922
#  Labelled attachment Score 0.7602739726027398
# Total lines : 4551.0
#  Unlabelled attachment Score 0.8497033618984838
#  Labelled attachment Score 0.7607119314436388
# Total lines : 4574.0
#  Unlabelled attachment Score 0.85002186270223
#  Labelled attachment Score 0.7610406646261478
# Total lines : 4594.0
#  Unlabelled attachment Score 0.8504571179799739
#  Labelled attachment Score 0.761427949499347
# Total lines : 4607.0
#  Unlabelled attachment Score 0.850662036032125
#  Labelled attachment Score 0.7618840894291296
# Total lines : 4614.0
#  Unlabelled attachment Score 0.8508885999133073
#  Labelled attachment Score 0.7622453402687472
# Total lines : 4622.0
#  Unlabelled attachment Score 0.850713976633492
#  Labelled attachment Score 0.7622241453916053
# Total lines : 4640.0
#  Unlabelled attachment Score 0.850646551724138
#  Labelled attachment Score 0.7616379310344827
# Total lines : 4649.0
#  Unlabelled attachment Score 0.8505054850505485
#  Labelled attachment Score 0.7614540761454076
# Total lines : 4676.0
#  Unlabelled attachment Score 0.850727117194183
#  Labelled attachment Score 0.7619760479041916
# Total lines : 4685.0
#  Unlabelled attachment Score 0.8510138740661686
#  Labelled attachment Score 0.7622198505869797
# Total lines : 4708.0
#  Unlabelled attachment Score 0.85089209855565
#  Labelled attachment Score 0.762107051826678
# Total lines : 4714.0
#  Unlabelled attachment Score 0.8510818837505303
#  Labelled attachment Score 0.7617734408145949
# Total lines : 4745.0
#  Unlabelled attachment Score 0.8512118018967334
#  Labelled attachment Score 0.7622760800842993
# Total lines : 4764.0
#  Unlabelled attachment Score 0.8511754827875735
#  Labelled attachment Score 0.762384550797649
# Total lines : 4785.0
#  Unlabelled attachment Score 0.8512016718913271
#  Labelled attachment Score 0.7623824451410658
# Total lines : 4825.0
#  Unlabelled attachment Score 0.8520207253886011
#  Labelled attachment Score 0.7635233160621762
# Total lines : 4866.0
#  Unlabelled attachment Score 0.852445540484998
#  Labelled attachment Score 0.7642827784628031
# Total lines : 4874.0
#  Unlabelled attachment Score 0.8526877308165778
#  Labelled attachment Score 0.7644645055395979
# Total lines : 4891.0
#  Unlabelled attachment Score 0.8527908403189531
#  Labelled attachment Score 0.7646698016765487
# Total lines : 4923.0
#  Unlabelled attachment Score 0.8523258175908999
#  Labelled attachment Score 0.7643713183018485
# Total lines : 4953.0
#  Unlabelled attachment Score 0.8514031899858672
#  Labelled attachment Score 0.7637795275590551
# Total lines : 4967.0
#  Unlabelled attachment Score 0.8514193678276626
#  Labelled attachment Score 0.7636400241594524
# Total lines : 4980.0
#  Unlabelled attachment Score 0.8518072289156626
#  Labelled attachment Score 0.763855421686747
# Total lines : 5000.0
#  Unlabelled attachment Score 0.8518
#  Labelled attachment Score 0.7642
# Total lines : 5010.0
#  Unlabelled attachment Score 0.8512974051896207
#  Labelled attachment Score 0.7636726546906187
# Total lines : 5027.0
#  Unlabelled attachment Score 0.8512035010940919
#  Labelled attachment Score 0.7638750745971753
# Total lines : 5041.0
#  Unlabelled attachment Score 0.8512199960325332
#  Labelled attachment Score 0.7641341003769093
# Total lines : 5058.0
#  Unlabelled attachment Score 0.8513246342427837
#  Labelled attachment Score 0.7645314353499407
# Total lines : 5074.0
#  Unlabelled attachment Score 0.8512022073314939
#  Labelled attachment Score 0.7646826960977533
# Total lines : 5084.0
#  Unlabelled attachment Score 0.851494885916601
#  Labelled attachment Score 0.7647521636506688
# Total lines : 5094.0
#  Unlabelled attachment Score 0.8515901060070671
#  Labelled attachment Score 0.765017667844523
# Total lines : 5106.0
#  Unlabelled attachment Score 0.8517430473952213
#  Labelled attachment Score 0.7651782216999609
# Total lines : 5112.0
#  Unlabelled attachment Score 0.8517214397496088
#  Labelled attachment Score 0.7652582159624414
# Total lines : 5123.0
#  Unlabelled attachment Score 0.852039820417724
#  Labelled attachment Score 0.7657622486824126
# Total lines : 5131.0
#  Unlabelled attachment Score 0.8520756187877607
#  Labelled attachment Score 0.765542779185344
# Total lines : 5147.0
#  Unlabelled attachment Score 0.8521468816786477
#  Labelled attachment Score 0.7653001748591413
# Total lines : 5165.0
#  Unlabelled attachment Score 0.852081316553727
#  Labelled attachment Score 0.7653436592449178
# Total lines : 5175.0
#  Unlabelled attachment Score 0.8523671497584541
#  Labelled attachment Score 0.7654106280193237
# Total lines : 5189.0
#  Unlabelled attachment Score 0.8521873193293505
#  Labelled attachment Score 0.7654654075929852
# Total lines : 5205.0
#  Unlabelled attachment Score 0.8522574447646494
#  Labelled attachment Score 0.765609990393852
# Total lines : 5213.0
#  Unlabelled attachment Score 0.8521005179359294
#  Labelled attachment Score 0.7655860349127181
# Total lines : 5232.0
#  Unlabelled attachment Score 0.8511085626911316
#  Labelled attachment Score 0.764717125382263
# Total lines : 5256.0
#  Unlabelled attachment Score 0.850076103500761
#  Labelled attachment Score 0.7636986301369864
# Total lines : 5311.0
#  Unlabelled attachment Score 0.8508755413293165
#  Labelled attachment Score 0.765016004518923
# Total lines : 5330.0
#  Unlabelled attachment Score 0.8502814258911819
#  Labelled attachment Score 0.7643527204502815
# Total lines : 5360.0
#  Unlabelled attachment Score 0.8496268656716418
#  Labelled attachment Score 0.7638059701492538
# Total lines : 5379.0
#  Unlabelled attachment Score 0.8497862056144265
#  Labelled attachment Score 0.7637107269009109
# Total lines : 5402.0
#  Unlabelled attachment Score 0.8491299518696779
#  Labelled attachment Score 0.7624953720844132
# Total lines : 5429.0
#  Unlabelled attachment Score 0.849511880641002
#  Labelled attachment Score 0.7627555719285319
# Total lines : 5455.0
#  Unlabelled attachment Score 0.8498625114573786
#  Labelled attachment Score 0.7629697525206233
# Total lines : 5472.0
#  Unlabelled attachment Score 0.8501461988304093
#  Labelled attachment Score 0.7631578947368421
# Total lines : 5487.0
#  Unlabelled attachment Score 0.8503736103517405
#  Labelled attachment Score 0.7636231091671223
# Total lines : 5507.0
#  Unlabelled attachment Score 0.8505538405665517
#  Labelled attachment Score 0.7635736335572907
# Total lines : 5529.0
#  Unlabelled attachment Score 0.8507867607162235
#  Labelled attachment Score 0.7639717851329354
# Total lines : 5542.0
#  Unlabelled attachment Score 0.8505954529050884
#  Labelled attachment Score 0.7638036809815951
# Total lines : 5566.0
#  Unlabelled attachment Score 0.850700682716493
#  Labelled attachment Score 0.764103485447359
# Total lines : 5575.0
#  Unlabelled attachment Score 0.8505829596412556
#  Labelled attachment Score 0.7639461883408072
# Total lines : 5627.0
#  Unlabelled attachment Score 0.8489425981873112
#  Labelled attachment Score 0.7631064510396304
# Total lines : 5633.0
#  Unlabelled attachment Score 0.8489259719510031
#  Labelled attachment Score 0.7628262027338896
# Total lines : 5642.0
#  Unlabelled attachment Score 0.8489897199574619
#  Labelled attachment Score 0.7628500531726338
# Total lines : 5660.0
#  Unlabelled attachment Score 0.8494699646643109
#  Labelled attachment Score 0.7634275618374559
# Total lines : 5726.0
#  Unlabelled attachment Score 0.8482361159622773
#  Labelled attachment Score 0.7630108278030039
# Total lines : 5746.0
#  Unlabelled attachment Score 0.8487643578141316
#  Labelled attachment Score 0.763661677688827
# Total lines : 5754.0
#  Unlabelled attachment Score 0.8489746263468891
#  Labelled attachment Score 0.7638164754953076
# Total lines : 5766.0
#  Unlabelled attachment Score 0.8491155046826223
#  Labelled attachment Score 0.7639611515782171
# Total lines : 5777.0
#  Unlabelled attachment Score 0.8492297039986152
#  Labelled attachment Score 0.7640643932837112
# Total lines : 5786.0
#  Unlabelled attachment Score 0.8492913930176288
#  Labelled attachment Score 0.7642585551330798
# Total lines : 5826.0
#  Unlabelled attachment Score 0.8492962581531067
#  Labelled attachment Score 0.7645039478201168
# Total lines : 5836.0
#  Unlabelled attachment Score 0.8495544893762851
#  Labelled attachment Score 0.7647361206305688
# Total lines : 5854.0
#  Unlabelled attachment Score 0.8498462589682269
#  Labelled attachment Score 0.7651178681243594
# Total lines : 5858.0
#  Unlabelled attachment Score 0.8499487879822465
#  Labelled attachment Score 0.7649368385114373
# Total lines : 5869.0
#  Unlabelled attachment Score 0.8500596353722951
#  Labelled attachment Score 0.765036633157267
# Total lines : 5899.0
#  Unlabelled attachment Score 0.8508221732497033
#  Labelled attachment Score 0.7653839633836244
# Total lines : 5924.0
#  Unlabelled attachment Score 0.8509453072248481
#  Labelled attachment Score 0.7658676569885212
# Total lines : 5947.0
#  Unlabelled attachment Score 0.8511854716663864
#  Labelled attachment Score 0.7664368589204641
# Total lines : 5965.0
#  Unlabelled attachment Score 0.8511316010058676
#  Labelled attachment Score 0.7659681475272423
# Total lines : 5976.0
#  Unlabelled attachment Score 0.8510709504685409
#  Labelled attachment Score 0.7658969210174029
# Total lines : 6006.0
#  Unlabelled attachment Score 0.8508158508158508
#  Labelled attachment Score 0.7652347652347652
# Total lines : 6034.0
#  Unlabelled attachment Score 0.8510109380178986
#  Labelled attachment Score 0.765661252900232
# Total lines : 6055.0
#  Unlabelled attachment Score 0.8510322047894302
#  Labelled attachment Score 0.7658133773740711
# Total lines : 6069.0
#  Unlabelled attachment Score 0.8512110726643599
#  Labelled attachment Score 0.7658592848904268
# Total lines : 6104.0
#  Unlabelled attachment Score 0.8510812581913499
#  Labelled attachment Score 0.7660550458715596
# Total lines : 6122.0
#  Unlabelled attachment Score 0.8511924207775237
#  Labelled attachment Score 0.7655994772950017
# Total lines : 6134.0
#  Unlabelled attachment Score 0.8508314313661558
#  Labelled attachment Score 0.7650798826214542
# Total lines : 6160.0
#  Unlabelled attachment Score 0.8509740259740259
#  Labelled attachment Score 0.7655844155844156
# Total lines : 6196.0
#  Unlabelled attachment Score 0.8505487411233054
#  Labelled attachment Score 0.7648482892188508
# Total lines : 6209.0
#  Unlabelled attachment Score 0.8507005959091641
#  Labelled attachment Score 0.7650185215010469
# Total lines : 6231.0
#  Unlabelled attachment Score 0.851067244423046
#  Labelled attachment Score 0.7653667148130316
# Total lines : 6268.0
#  Unlabelled attachment Score 0.8508296107211232
#  Labelled attachment Score 0.7651563497128271
# Total lines : 6279.0
#  Unlabelled attachment Score 0.8510909380474598
#  Labelled attachment Score 0.765249243510113
# Total lines : 6298.0
#  Unlabelled attachment Score 0.8512226103524928
#  Labelled attachment Score 0.7651635439822165
# Total lines : 6313.0
#  Unlabelled attachment Score 0.8512593061935688
#  Labelled attachment Score 0.7652463171233962
# Total lines : 6330.0
#  Unlabelled attachment Score 0.8513428120063191
#  Labelled attachment Score 0.7654028436018957
# Total lines : 6336.0
#  Unlabelled attachment Score 0.8513257575757576
#  Labelled attachment Score 0.7653093434343434
# Total lines : 6367.0
#  Unlabelled attachment Score 0.8507931521909847
#  Labelled attachment Score 0.7648814198209518
# Total lines : 6385.0
#  Unlabelled attachment Score 0.8507439310884887
#  Labelled attachment Score 0.7649177760375881
# Total lines : 6414.0
#  Unlabelled attachment Score 0.8506392266916121
#  Labelled attachment Score 0.7650452135952603
# Total lines : 6423.0
#  Unlabelled attachment Score 0.8505371321812237
#  Labelled attachment Score 0.7649073641600498
# Total lines : 6441.0
#  Unlabelled attachment Score 0.8507995652848936
#  Labelled attachment Score 0.7654090979661543
# Total lines : 6460.0
#  Unlabelled attachment Score 0.8510835913312693
#  Labelled attachment Score 0.7651702786377709
# Total lines : 6480.0
#  Unlabelled attachment Score 0.850925925925926
#  Labelled attachment Score 0.7651234567901235
# Total lines : 6516.0
#  Unlabelled attachment Score 0.850061387354205
#  Labelled attachment Score 0.7642725598526704
# Total lines : 6544.0
#  Unlabelled attachment Score 0.8502444987775061
#  Labelled attachment Score 0.7646699266503667
# Total lines : 6569.0
#  Unlabelled attachment Score 0.8505099710762674
#  Labelled attachment Score 0.7648043842289541
# Total lines : 6583.0
#  Unlabelled attachment Score 0.850675983594106
#  Labelled attachment Score 0.7650007595321282
# Total lines : 6593.0
#  Unlabelled attachment Score 0.8509024723191263
#  Labelled attachment Score 0.76535719702715
# Total lines : 6602.0
#  Unlabelled attachment Score 0.8508027870342321
#  Labelled attachment Score 0.7650711905483187
# Total lines : 6612.0
#  Unlabelled attachment Score 0.8508771929824561
#  Labelled attachment Score 0.765124016938899
# Total lines : 6637.0
#  Unlabelled attachment Score 0.8511375621515745
#  Labelled attachment Score 0.7652553864697905
# Total lines : 6644.0
#  Unlabelled attachment Score 0.8512944009632751
#  Labelled attachment Score 0.7655027092113185
# Total lines : 6665.0
#  Unlabelled attachment Score 0.8511627906976744
#  Labelled attachment Score 0.7656414103525881
# Total lines : 6685.0
#  Unlabelled attachment Score 0.8508601346297682
#  Labelled attachment Score 0.7655946148092745
# Total lines : 6709.0
#  Unlabelled attachment Score 0.8509464897898346
#  Labelled attachment Score 0.7659859889700402
# Total lines : 6724.0
#  Unlabelled attachment Score 0.8511302795954789
#  Labelled attachment Score 0.7662105889351577
# Total lines : 6739.0
#  Unlabelled attachment Score 0.8511648612553792
#  Labelled attachment Score 0.7662857990799822
# Total lines : 6751.0
#  Unlabelled attachment Score 0.8514294178640202
#  Labelled attachment Score 0.7667012294474893
# Total lines : 6766.0
#  Unlabelled attachment Score 0.850872007094295
#  Labelled attachment Score 0.7661838604788649
# Total lines : 6786.0
#  Unlabelled attachment Score 0.8511641615089891
#  Labelled attachment Score 0.765988800471559
# Total lines : 6800.0
#  Unlabelled attachment Score 0.8508823529411764
#  Labelled attachment Score 0.7657352941176471
# Total lines : 6807.0
#  Unlabelled attachment Score 0.8510356985456148
#  Labelled attachment Score 0.7658292933744675
# Total lines : 6827.0
#  Unlabelled attachment Score 0.8507397099750988
#  Labelled attachment Score 0.7654899663102388
# Total lines : 6843.0
#  Unlabelled attachment Score 0.8506502995762093
#  Labelled attachment Score 0.7651614788835306
# Total lines : 6874.0
#  Unlabelled attachment Score 0.8507419260983415
#  Labelled attachment Score 0.7652022112307245
# Total lines : 6885.0
#  Unlabelled attachment Score 0.8506899055918664
#  Labelled attachment Score 0.7651416122004358
# Total lines : 6900.0
#  Unlabelled attachment Score 0.8505797101449275
#  Labelled attachment Score 0.7652173913043478
# Total lines : 6908.0
#  Unlabelled attachment Score 0.8507527504342791
#  Labelled attachment Score 0.7653445280833816
# Total lines : 6916.0
#  Unlabelled attachment Score 0.8507807981492193
#  Labelled attachment Score 0.7654713707345286
# Total lines : 6930.0
#  Unlabelled attachment Score 0.8510822510822511
#  Labelled attachment Score 0.7659451659451659
# Total lines : 6948.0
#  Unlabelled attachment Score 0.8513241220495107
#  Labelled attachment Score 0.7662636729994243
# Total lines : 6982.0
#  Unlabelled attachment Score 0.8506158693784016
#  Labelled attachment Score 0.7659696362073904
# Total lines : 6996.0
#  Unlabelled attachment Score 0.8507718696397941
#  Labelled attachment Score 0.7661520869068039
# Total lines : 7003.0
# ...
#  Unlabelled attachment Score 0.8649991578238168
#  Labelled attachment Score 0.7750547414519118
# Total lines : 23763.0
#  Unlabelled attachment Score 0.865084374868493
#  Labelled attachment Score 0.77515465219038
# Total lines : 23791.0
#  Unlabelled attachment Score 0.8651170610735152
#  Labelled attachment Score 0.7752511453911143
# Total lines : 23816.0
#  Unlabelled attachment Score 0.865174672489083
#  Labelled attachment Score 0.7751931474638898
# Total lines : 23851.0
#  Unlabelled attachment Score 0.8652048132153788
#  Labelled attachment Score 0.7752714770869146
# Total lines : 23875.0
#  Unlabelled attachment Score 0.8652565445026178
#  Labelled attachment Score 0.7752879581151833
# Total lines : 23882.0
#  Unlabelled attachment Score 0.8652541663177288
#  Labelled attachment Score 0.7752700778829243
# Total lines : 23912.0
#  Unlabelled attachment Score 0.8653813984610238
#  Labelled attachment Score 0.7753429240548678
# Total lines : 23932.0
#  Unlabelled attachment Score 0.8654103292662544
#  Labelled attachment Score 0.7753217449440081
# Total lines : 23969.0
#  Unlabelled attachment Score 0.865451207810088
#  Labelled attachment Score 0.7752930869039175
# Total lines : 23985.0
#  Unlabelled attachment Score 0.8654992703773191
#  Labelled attachment Score 0.7752762143006046
# Total lines : 24010.0
#  Unlabelled attachment Score 0.8655143690129112
#  Labelled attachment Score 0.775177009579342
# Total lines : 24023.0
#  Unlabelled attachment Score 0.8655871456520834
#  Labelled attachment Score 0.7751737917828747
# Total lines : 24064.0
#  Unlabelled attachment Score 0.865483710106383
#  Labelled attachment Score 0.775141289893617
# Total lines : 24078.0
#  Unlabelled attachment Score 0.8654373286817842
#  Labelled attachment Score 0.7750228424287732
# Total lines : 24108.0
#  Unlabelled attachment Score 0.8653973784635806
#  Labelled attachment Score 0.7749709639953543
# Total lines : 24118.0
#  Unlabelled attachment Score 0.8654531884899246
#  Labelled attachment Score 0.7749813417364624
# Total lines : 24130.0
#  Unlabelled attachment Score 0.8655200994612515
#  Labelled attachment Score 0.7750518027351844
# Total lines : 24145.0
#  Unlabelled attachment Score 0.8655208117622696
#  Labelled attachment Score 0.7750673017187824
# Total lines : 24154.0
#  Unlabelled attachment Score 0.8653225138693384
#  Labelled attachment Score 0.7749027076260661
# Total lines : 24162.0
#  Unlabelled attachment Score 0.8653671053720718
#  Labelled attachment Score 0.7748944623789421
# Total lines : 24192.0
#  Unlabelled attachment Score 0.865244708994709
#  Labelled attachment Score 0.7747602513227513
# Total lines : 24203.0
#  Unlabelled attachment Score 0.8653059538073793
#  Labelled attachment Score 0.7747799859521547
# Total lines : 24223.0
#  Unlabelled attachment Score 0.8653758824257937
#  Labelled attachment Score 0.774924658382529
# Total lines : 24235.0
#  Unlabelled attachment Score 0.8653600165050547
#  Labelled attachment Score 0.7748710542603673
# Total lines : 24249.0
#  Unlabelled attachment Score 0.8653552723823663
#  Labelled attachment Score 0.7748773145284341
# Total lines : 24260.0
#  Unlabelled attachment Score 0.8653751030502885
#  Labelled attachment Score 0.7748969497114592
# Total lines : 24294.0
#  Unlabelled attachment Score 0.8653165390631432
#  Labelled attachment Score 0.7749238495101671
# Total lines : 24313.0
#  Unlabelled attachment Score 0.8653395302924362
#  Labelled attachment Score 0.7749352198412371
# Total lines : 24331.0
#  Unlabelled attachment Score 0.8653569520364967
#  Labelled attachment Score 0.7748140232625046
# Total lines : 24363.0
#  Unlabelled attachment Score 0.8652464803185158
#  Labelled attachment Score 0.7746582933136313
# Total lines : 24373.0
#  Unlabelled attachment Score 0.8653017683502237
#  Labelled attachment Score 0.7746686907643704
# Total lines : 24381.0
#  Unlabelled attachment Score 0.8653459661211599
#  Labelled attachment Score 0.7747016119109142
# Total lines : 24406.0
#  Unlabelled attachment Score 0.8651561091534868
#  Labelled attachment Score 0.774399737769401
# Total lines : 24418.0
#  Unlabelled attachment Score 0.8650995167499386
#  Labelled attachment Score 0.7743467933491687
# Total lines : 24432.0
#  Unlabelled attachment Score 0.8650949574328749
#  Labelled attachment Score 0.7743533071381794
# Total lines : 24471.0
#  Unlabelled attachment Score 0.8650647705447264
#  Labelled attachment Score 0.7743042785337747
# Total lines : 24499.0
#  Unlabelled attachment Score 0.8649740805747174
#  Labelled attachment Score 0.7742356830891057
# Total lines : 24541.0
#  Unlabelled attachment Score 0.8650829224562976
#  Labelled attachment Score 0.7741738315472068
# Total lines : 24557.0
#  Unlabelled attachment Score 0.8651301054689091
#  Labelled attachment Score 0.7741988027853565
# Total lines : 24573.0
#  Unlabelled attachment Score 0.8649737516786717
#  Labelled attachment Score 0.7741016562894234
# Total lines : 24586.0
#  Unlabelled attachment Score 0.865004474090946
#  Labelled attachment Score 0.7740584072236232
# Total lines : 24599.0
#  Unlabelled attachment Score 0.8649538599130046
#  Labelled attachment Score 0.774015203870076
# Total lines : 24608.0
#  Unlabelled attachment Score 0.8649219765929779
#  Labelled attachment Score 0.7739759427828349
# Total lines : 24616.0
#  Unlabelled attachment Score 0.8649658758531037
#  Labelled attachment Score 0.7740087747806305
# Total lines : 24634.0
#  Unlabelled attachment Score 0.8648615734350897
#  Labelled attachment Score 0.7739303401802387
# Total lines : 24643.0
#  Unlabelled attachment Score 0.8648703485776894
#  Labelled attachment Score 0.773891165848314
# Total lines : 24647.0
#  Unlabelled attachment Score 0.8648922789791861
#  Labelled attachment Score 0.7739278614030105
# Total lines : 24654.0
#  Unlabelled attachment Score 0.8649306400584084
#  Labelled attachment Score 0.7738703658635515
# Total lines : 24665.0
#  Unlabelled attachment Score 0.8649503344820596
#  Labelled attachment Score 0.7738495844313805
# Total lines : 24671.0
#  Unlabelled attachment Score 0.8649831786307811
#  Labelled attachment Score 0.7738640509099752
# Total lines : 24693.0
#  Unlabelled attachment Score 0.8649414813914875
#  Labelled attachment Score 0.7738630381079659
# Total lines : 24707.0
#  Unlabelled attachment Score 0.8649775367304813
#  Labelled attachment Score 0.7739102278706439
# Total lines : 24717.0
#  Unlabelled attachment Score 0.8649917061132014
#  Labelled attachment Score 0.7738803252821944
# Total lines : 24737.0
#  Unlabelled attachment Score 0.8649795852366899
#  Labelled attachment Score 0.7738610179083963
# Total lines : 24755.0
#  Unlabelled attachment Score 0.864916178549788
#  Labelled attachment Score 0.7738638658856797
# Total lines : 24779.0
#  Unlabelled attachment Score 0.8649259453569554
#  Labelled attachment Score 0.7737600387424836
# Total lines : 24796.0
#  Unlabelled attachment Score 0.8648975641232457
#  Labelled attachment Score 0.7736328440070979
# Total lines : 24807.0
#  Unlabelled attachment Score 0.8649574716813803
#  Labelled attachment Score 0.7736122868545169
# Total lines : 24843.0
#  Unlabelled attachment Score 0.8647908867689087
#  Labelled attachment Score 0.7734170591313448
# Total lines : 24848.0
#  Unlabelled attachment Score 0.8648180940115905
#  Labelled attachment Score 0.7734626529298133
# Total lines : 24873.0
#  Unlabelled attachment Score 0.8647529449603988
#  Labelled attachment Score 0.7734893257749367
# Total lines : 24898.0
#  Unlabelled attachment Score 0.8647682544782713
#  Labelled attachment Score 0.7735561089244116
# Total lines : 24903.0
#  Unlabelled attachment Score 0.8647954061759627
#  Labelled attachment Score 0.7736015741075373
# Total lines : 24924.0
#  Unlabelled attachment Score 0.8647087144920559
#  Labelled attachment Score 0.7735515968544375
# Total lines : 24945.0
#  Unlabelled attachment Score 0.8647424333533774
#  Labelled attachment Score 0.7736219683303267
# Total lines : 24977.0
#  Unlabelled attachment Score 0.8647555751291188
#  Labelled attachment Score 0.7737118148696801
# Total lines : 24993.0
#  Unlabelled attachment Score 0.8647621333973513
#  Labelled attachment Score 0.77377665746409
# Total lines : 25006.0
#  Unlabelled attachment Score 0.8647924498120451
#  Labelled attachment Score 0.7738542749740063
# Total lines : 25024.0
#  Unlabelled attachment Score 0.8648097826086957
#  Labelled attachment Score 0.7738171355498721
# Total lines : 25039.0
#  Unlabelled attachment Score 0.8648508327009865
#  Labelled attachment Score 0.7737928831023603
# Total lines : 25062.0
#  Unlabelled attachment Score 0.8648950602505786
#  Labelled attachment Score 0.7738408746309153
# Total lines : 25099.0
#  Unlabelled attachment Score 0.8647754890633093
#  Labelled attachment Score 0.7736563209689629
# Total lines : 25122.0
#  Unlabelled attachment Score 0.8646206512220365
#  Labelled attachment Score 0.7734654884165273
# Total lines : 25161.0
#  Unlabelled attachment Score 0.864472795198919
#  Labelled attachment Score 0.7732602042844084
# Total lines : 25198.0
#  Unlabelled attachment Score 0.8644733709024526
#  Labelled attachment Score 0.7732756567981586
# Total lines : 25212.0
#  Unlabelled attachment Score 0.8643899730287165
#  Labelled attachment Score 0.7731635729017928
# Total lines : 25225.0
#  Unlabelled attachment Score 0.8644598612487612
#  Labelled attachment Score 0.773201189296333
# Total lines : 25260.0
#  Unlabelled attachment Score 0.8644497228820269
#  Labelled attachment Score 0.7731987331749802
# Total lines : 25276.0
#  Unlabelled attachment Score 0.864495964551353
#  Labelled attachment Score 0.7731049216648204
# Total lines : 25285.0
#  Unlabelled attachment Score 0.8645046470239273
#  Labelled attachment Score 0.773146134071584
# Total lines : 25296.0
#  Unlabelled attachment Score 0.8645635673624289
#  Labelled attachment Score 0.7732052498418722
# Total lines : 25313.0
#  Unlabelled attachment Score 0.8646545253427093
#  Labelled attachment Score 0.7733180579149054
# Total lines : 25333.0
#  Unlabelled attachment Score 0.8645640074211502
#  Labelled attachment Score 0.773181226068764
# Total lines : 25362.0
#  Unlabelled attachment Score 0.8644822963488684
#  Labelled attachment Score 0.77316457692611
# Total lines : 25375.0
#  Unlabelled attachment Score 0.864512315270936
#  Labelled attachment Score 0.7731231527093596
# Total lines : 25399.0
#  Unlabelled attachment Score 0.8644828536556557
#  Labelled attachment Score 0.7731406748297177
# Total lines : 25431.0
#  Unlabelled attachment Score 0.8643387991034565
#  Labelled attachment Score 0.7730722346742165
# Total lines : 25463.0
#  Unlabelled attachment Score 0.8642343792954483
#  Labelled attachment Score 0.7730039665396851
# Total lines : 25491.0
#  Unlabelled attachment Score 0.864226589776784
#  Labelled attachment Score 0.7730963869601035
# Total lines : 25497.0
#  Unlabelled attachment Score 0.8642193199199906
#  Labelled attachment Score 0.7730713417264776
# Total lines : 25530.0
#  Unlabelled attachment Score 0.864003133568351
#  Labelled attachment Score 0.772816294555425
# Total lines : 25564.0
#  Unlabelled attachment Score 0.8639884212173369
#  Labelled attachment Score 0.7728055077452668
# Total lines : 25579.0
#  Unlabelled attachment Score 0.8640290863599046
#  Labelled attachment Score 0.7728605496696509
# Total lines : 25587.0
#  Unlabelled attachment Score 0.8640715988587955
#  Labelled attachment Score 0.7728924844647672
# Total lines : 25594.0
#  Unlabelled attachment Score 0.8641087754942565
#  Labelled attachment Score 0.7729545987340783
# Total lines : 25621.0
#  Unlabelled attachment Score 0.864056828382967
#  Labelled attachment Score 0.7729206510284532
# Total lines : 25634.0
#  Unlabelled attachment Score 0.8640867597721775
#  Labelled attachment Score 0.7729577904345791
# Total lines : 25647.0
#  Unlabelled attachment Score 0.8641166608180294
#  Labelled attachment Score 0.7729169103598862
# Total lines : 25685.0
#  Unlabelled attachment Score 0.863928362857699
#  Labelled attachment Score 0.7727856725715399
# Total lines : 25706.0
#  Unlabelled attachment Score 0.8640395238465728
#  Labelled attachment Score 0.7728934879016572
# Total lines : 25732.0
#  Unlabelled attachment Score 0.8640214518886989
#  Labelled attachment Score 0.7728897870355977
# Total lines : 25741.0
#  Unlabelled attachment Score 0.8638747523406239
#  Labelled attachment Score 0.7727749504681248
# Total lines : 25765.0
#  Unlabelled attachment Score 0.8638463031243936
#  Labelled attachment Score 0.7727537356879488
# Total lines : 25775.0
#  Unlabelled attachment Score 0.8638991270611057
#  Labelled attachment Score 0.7728031037827352
# Total lines : 25788.0
#  Unlabelled attachment Score 0.8639289592058321
#  Labelled attachment Score 0.7728400806576702
# Total lines : 25801.0
#  Unlabelled attachment Score 0.8638424867253207
#  Labelled attachment Score 0.7727607457075307
# Total lines : 25812.0
#  Unlabelled attachment Score 0.8638617697195103
#  Labelled attachment Score 0.7727801022780102
# Total lines : 25832.0
#  Unlabelled attachment Score 0.8639284608237845
#  Labelled attachment Score 0.7728398885103748
# Total lines : 25846.0
#  Unlabelled attachment Score 0.863924785266579
#  Labelled attachment Score 0.7728468621837035
# Total lines : 25866.0
#  Unlabelled attachment Score 0.8639140184025361
#  Labelled attachment Score 0.7728678574190057
# Total lines : 25892.0
#  Unlabelled attachment Score 0.8639348061177198
#  Labelled attachment Score 0.7729028271280705
# Total lines : 25904.0
#  Unlabelled attachment Score 0.8639978381717109
#  Labelled attachment Score 0.7730080296479308
# Total lines : 25917.0
#  Unlabelled attachment Score 0.8640274723154686
#  Labelled attachment Score 0.773044719682062
# Total lines : 25940.0
#  Unlabelled attachment Score 0.864070932922128
#  Labelled attachment Score 0.773053199691596
# Total lines : 25974.0
#  Unlabelled attachment Score 0.8641718641718642
#  Labelled attachment Score 0.7732347732347732
# Total lines : 25995.0
#  Unlabelled attachment Score 0.8640123100596269
#  Labelled attachment Score 0.7731486824389305
# Total lines : 26015.0
#  Unlabelled attachment Score 0.8640784162982894
#  Labelled attachment Score 0.7732077647511051
# Total lines : 26030.0
#  Unlabelled attachment Score 0.8641567422205148
#  Labelled attachment Score 0.773300038417211
# Total lines : 26047.0
#  Unlabelled attachment Score 0.8641686182669789
#  Labelled attachment Score 0.7732176450262986
# Total lines : 26060.0
#  Unlabelled attachment Score 0.8642363775901765
#  Labelled attachment Score 0.7732924021488872
# Total lines : 26070.0
#  Unlabelled attachment Score 0.8642884541618718
#  Labelled attachment Score 0.7733410049865747
# Total lines : 26080.0
#  Unlabelled attachment Score 0.8643021472392638
#  Labelled attachment Score 0.7733895705521472
# Total lines : 26101.0
#  Unlabelled attachment Score 0.864296387111605
#  Labelled attachment Score 0.7734186429638711
# Total lines : 26132.0
#  Unlabelled attachment Score 0.8643043012398591
#  Labelled attachment Score 0.7734195622225624
# Total lines : 26145.0
#  Unlabelled attachment Score 0.8643717728055077
#  Labelled attachment Score 0.7734939759036145
# Total lines : 26159.0
#  Unlabelled attachment Score 0.8644443594938644
#  Labelled attachment Score 0.7735387438357736
# Total lines : 26169.0
#  Unlabelled attachment Score 0.8644579464251595
#  Labelled attachment Score 0.7735106423631014
# Total lines : 26196.0
#  Unlabelled attachment Score 0.8644449534280043
#  Labelled attachment Score 0.7735913879981676
# Total lines : 26209.0
#  Unlabelled attachment Score 0.8644358808043039
#  Labelled attachment Score 0.7735510702430463
# Total lines : 26234.0
#  Unlabelled attachment Score 0.8643744758710071
#  Labelled attachment Score 0.7735762750628955
# Total lines : 26253.0
#  Unlabelled attachment Score 0.8642821772749781
#  Labelled attachment Score 0.7734354169047347
# Total lines : 26264.0
#  Unlabelled attachment Score 0.8642628693268352
#  Labelled attachment Score 0.7734160828510509
# Total lines : 26282.0
#  Unlabelled attachment Score 0.8643177840347006
#  Labelled attachment Score 0.7734951677954494
# Total lines : 26301.0
#  Unlabelled attachment Score 0.8643397589445269
#  Labelled attachment Score 0.7735827535074712
# Total lines : 26341.0
#  Unlabelled attachment Score 0.8640522379560381
#  Labelled attachment Score 0.7733571238753274

# %%
import pickle

filename = 'dependency_parsing_model.sav'
pickle.dump(model3, open(filename, 'wb'))

# %%
import pickle

loaded_model = pickle.load(open(filename, 'rb'))

# %%
# %%time

# model2 = dp.train(x_train,y_train,'bnb')


# %%time

# accuracy2 = dp.evaluate(test_treebank,model)

# %%
    
#         print(f'{(word_st_top,word_st_2ndtop,word_st_3rdtop)}')
#         print(f'{(POS_st_top,POS_st_2ndtop,POS_st_3rdtop)}')
#         print(f'{( word_buf_top,word_buf_2ndtop,word_buf_3rdtop)}')
#         print(f'{(POS_buf_top,POS_buf_2ndtop,POS_buf_3rdtop)}')
#         print(f'{(bufleft_word_val,bufleft_word_child1,bufleft_word_child2)}')
#         print(f'{(bufleft_tag_val,bufleft_tag_child1,bufleft_tag_child2)}')
#         print(f'{( bufright_word_val,bufright_word_child1,bufright_word_child2)}')
#         print(f'{(bufright_tag_val,bufright_tag_child1,bufright_tag_child2)}')
#         print(f'{(stleft_word_val,stleft_word_child1,stleft_word_child2)}')
#         print(f'{(stleft_tag_val,stleft_tag_child1,stleft_tag_child2)}')
#         print(f'{( stright_word_val,stright_word_child1,stright_word_child2)}')
#         print(f'{(stright_tag_val,stright_tag_child1,stright_tag_child2)}')
#         print('-'*50)
